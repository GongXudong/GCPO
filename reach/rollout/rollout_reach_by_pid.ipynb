# %%
from rollout_by_pid import rollout
import pandas as pd

# %%
TOTAL_TIMESTEPS = 10_000
GOAL_RANGE = 0.1
SPEED = 1.0

# %%
dict_logs = rollout(total_timesteps=TOTAL_TIMESTEPS, goal_range=GOAL_RANGE, speed=SPEED)
# Out:
# pybullet build time: May 20 2022 19:44:17
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# -26.58011049723757
# 27.58011049723757
# 362
# 10000

# %%
data_df = pd.DataFrame(dict_logs)
data_df
# Out:
#            s_x           s_y       s_z     s_v_x     s_v_y     s_v_z  \
# 0     0.038440 -2.194472e-12  0.197400  0.000000 -0.000000  0.000000
# 1     0.036724 -7.804155e-04  0.192341 -0.016144 -0.006019 -0.045496
# 2     0.035009 -1.534254e-03  0.187431 -0.014866 -0.005693 -0.041028
# 3     0.033327 -2.256190e-03  0.182720 -0.014537 -0.005457 -0.039335
# 4     0.031674 -2.947033e-03  0.178200 -0.014184 -0.005223 -0.037581
# ...        ...           ...       ...       ...       ...       ...
# 9995  0.017089 -2.994004e-03  0.146922 -0.014484 -0.001657 -0.030029
# 9996  0.015391 -3.200538e-03  0.143372 -0.014046 -0.001595 -0.028711
# 9997  0.013737 -3.398055e-03  0.139969 -0.013612 -0.001523 -0.027455
# 9998  0.012126 -3.586927e-03  0.136709 -0.013185 -0.001469 -0.026253
# 9999  0.010560 -3.767527e-03  0.133584 -0.012765 -0.001414 -0.025100
#
#          s_g_x     s_g_y     s_g_z       a_x       a_y       a_z
# 0    -0.021698 -0.017988  0.075316 -0.060138 -0.017988 -0.122085
# ...

# %%
data_df.to_csv(f"reach_toal_{TOTAL_TIMESTEPS}_range_{GOAL_RANGE:.1f}_speed_{SPEED:.1f}.csv", index=False)

# %%
tmp = pd.read_csv(f"reach_toal_{TOTAL_TIMESTEPS}_range_{GOAL_RANGE:.1f}_speed_{SPEED:.1f}.csv")
tmp
# Out:
#            s_x           s_y       s_z     s_v_x     s_v_y     s_v_z  \
# 0     0.038440 -2.194472e-12  0.197400  0.000000 -0.000000  0.000000
# 1     0.036724 -7.804155e-04  0.192341 -0.016144 -0.006019 -0.045496
# 2     0.035009 -1.534254e-03  0.187431 -0.014866 -0.005693 -0.041028
# 3     0.033327 -2.256190e-03  0.182721 -0.014537 -0.005457 -0.039335
# 4     0.031674 -2.947033e-03  0.178200 -0.014184 -0.005223 -0.037581
# ...        ...           ...       ...       ...       ...       ...
# 9995  0.017089 -2.994004e-03  0.146922 -0.014484 -0.001657 -0.030029
# 9996  0.015391 -3.200538e-03  0.143372 -0.014046 -0.001595 -0.028711
# 9997  0.013737 -3.398054e-03  0.139969 -0.013612 -0.001523 -0.027455
# 9998  0.012126 -3.586927e-03  0.136709 -0.013185 -0.001469 -0.026253
# 9999  0.010560 -3.767527e-03  0.133584 -0.012765 -0.001414 -0.025100
#
#          s_g_x     s_g_y     s_g_z       a_x       a_y       a_z
# 0    -0.021698 -0.017988  0.075316 -0.060138 -0.017988 -0.122085
# ...
