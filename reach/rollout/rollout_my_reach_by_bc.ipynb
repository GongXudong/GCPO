# %% [markdown]
# # 以固定间隔枚举目标空间采样

# %%
from pathlib import Path
import sys
import gymnasium as gym
import panda_gym
import numpy as np
import pandas as pd
from gymnasium.envs.registration import register
from gymnasium.wrappers import FlattenObservation

PROJECT_ROOT_DIR = Path().absolute().parent
PROJECT_ROOT_DIR

if str(PROJECT_ROOT_DIR.absolute()) not in sys.path:
    sys.path.append(str(PROJECT_ROOT_DIR.absolute()))

from rollout.rollout_by_policy import rollout_by_goal_with_policy
from utils.sb3_env_wrappers import ScaledObservationWrapper
from my_reach_env import MyPandaReachEnv
from utils.load_data import load_data, split_data
from models.sb3_model import PPOWithBCLoss

# %%
goal_range = 0.3
distance_threshold = 0.01
EXPERIMENT_NAME = "iter_3/reacher_256_256_100epochs_loss_5"
# EXPERT_DATA_CACHE_DIR = "rollout/cache/myreach_pid_speed_1.5.csv"
EXPERT_DATA_CACHE_DIR = "rollout/cache/myreach_from_iter_2_rl_bc.csv"
csv_save_name = "iter_3_myreach_bc_5.csv"

# %%
register(
    id="my-reach",
    entry_point=f"my_reach_env:MyPandaReachEnv",
    kwargs={"reward_type": "sparse", "control_type": "ee", "goal_range": goal_range, "distance_threshold": distance_threshold},
    max_episode_steps=50,
)
# Out:
# /home/ucav/anaconda3/envs/panda_gym/lib/python3.8/site-packages/gymnasium/envs/registration.py:693: UserWarning: WARN: Overriding environment my-reach already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")

# %%
data_file: Path = PROJECT_ROOT_DIR / EXPERT_DATA_CACHE_DIR
scaled_obs, acts, infos, obs_scaler = load_data(data_file)

env = gym.make("my-reach")
env = ScaledObservationWrapper(env=FlattenObservation(env), scaler=obs_scaler)
# Out:
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886

# %%
# load policy
policy_save_dir = PROJECT_ROOT_DIR / "checkpoints" / "bc" / EXPERIMENT_NAME
algo_ppo = PPOWithBCLoss.load(str((policy_save_dir / "bc_checkpoint").absolute()))

# %%
success_cnt = 0
total_df = None
goal_range_int = int(goal_range * 100)
speed=2
x_low, x_high = -int(goal_range_int/2), int(goal_range_int/2)
y_low, y_high = -int(goal_range_int/2), int(goal_range_int/2)
z_low, z_high = 0, int(goal_range_int)
for x in range(x_low, x_high+1, 2):
    for y in range(y_low, y_high+1, 2):
        for z in range(z_low, z_high+1, 2):
            terminated, truncated, traj = rollout_by_goal_with_policy(env=env, goal=np.array([x/100., y/100., z/100.]), policy=algo_ppo.policy)
            if terminated:
                if total_df is None:
                    total_df = pd.DataFrame(traj)
                else:
                    total_df = pd.concat([total_df, pd.DataFrame(traj)])
                success_cnt += 1

success_cnt
# Out:
#  truncated. goal: (-0.15, -0.15, 0.0), steps: 50
#  truncated. goal: (-0.15, -0.15, 0.02), steps: 50
#  truncated. goal: (-0.15, -0.15, 0.04), steps: 50
#  truncated. goal: (-0.15, -0.15, 0.06), steps: 50
#  truncated. goal: (-0.15, -0.15, 0.08), steps: 50
#  truncated. goal: (-0.15, -0.15, 0.1), steps: 50
#  truncated. goal: (-0.15, -0.15, 0.12), steps: 50
#  truncated. goal: (-0.15, -0.15, 0.14), steps: 50
#  truncated. goal: (-0.15, -0.15, 0.16), steps: 50
#  success. goal: (-0.15, -0.15, 0.18), steps: 11
#  success. goal: (-0.15, -0.15, 0.2), steps: 10
#  success. goal: (-0.15, -0.15, 0.22), steps: 10
#  success. goal: (-0.15, -0.15, 0.24), steps: 9
#  success. goal: (-0.15, -0.15, 0.26), steps: 9
#  success. goal: (-0.15, -0.15, 0.28), steps: 9
#  truncated. goal: (-0.15, -0.15, 0.3), steps: 50
#  truncated. goal: (-0.15, -0.13, 0.0), steps: 50
#  truncated. goal: (-0.15, -0.13, 0.02), steps: 50
#  truncated. goal: (-0.15, -0.13, 0.04), steps: 50
#  truncated. goal: (-0.15, -0.13, 0.06), steps: 50
#  truncated. goal: (-0.15, -0.13, 0.08), steps: 50
#  truncated. goal: (-0.15, -0.13, 0.1), steps: 50
#  truncated. goal: (-0.15, -0.13, 0.12), steps: 50
#  truncated. goal: (-0.15, -0.13, 0.14), steps: 50
#  truncated. goal: (-0.15, -0.13, 0.16), steps: 50
#  truncated. goal: (-0.15, -0.13, 0.18), steps: 50
#  success. goal: (-0.15, -0.13, 0.2), steps: 7
#  success. goal: (-0.15, -0.13, 0.22), steps: 9
#  success. goal: (-0.15, -0.13, 0.24), steps: 8
#  success. goal: (-0.15, -0.13, 0.26), steps: 8
#  success. goal: (-0.15, -0.13, 0.28), steps: 8
#  success. goal: (-0.15, -0.13, 0.3), steps: 8
#  truncated. goal: (-0.15, -0.11, 0.0), steps: 50
#  truncated. goal: (-0.15, -0.11, 0.02), steps: 50
#  truncated. goal: (-0.15, -0.11, 0.04), steps: 50
#  truncated. goal: (-0.15, -0.11, 0.06), steps: 50
#  truncated. goal: (-0.15, -0.11, 0.08), steps: 50
#  truncated. goal: (-0.15, -0.11, 0.1), steps: 50
#  truncated. goal: (-0.15, -0.11, 0.12), steps: 50
#  truncated. goal: (-0.15, -0.11, 0.14), steps: 50
#  truncated. goal: (-0.15, -0.11, 0.16), steps: 50
#  truncated. goal: (-0.15, -0.11, 0.18), steps: 50
#  success. goal: (-0.15, -0.11, 0.2), steps: 8
#  success. goal: (-0.15, -0.11, 0.22), steps: 7
#  success. goal: (-0.15, -0.11, 0.24), steps: 7
#  success. goal: (-0.15, -0.11, 0.26), steps: 7
#  success. goal: (-0.15, -0.11, 0.28), steps: 7
#  success. goal: (-0.15, -0.11, 0.3), steps: 8
#  truncated. goal: (-0.15, -0.09, 0.0), steps: 50
#  truncated. goal: (-0.15, -0.09, 0.02), steps: 50
#  truncated. goal: (-0.15, -0.09, 0.04), steps: 50
#  truncated. goal: (-0.15, -0.09, 0.06), steps: 50
#  truncated. goal: (-0.15, -0.09, 0.08), steps: 50
#  truncated. goal: (-0.15, -0.09, 0.1), steps: 50
#  truncated. goal: (-0.15, -0.09, 0.12), steps: 50
#  truncated. goal: (-0.15, -0.09, 0.14), steps: 50
#  truncated. goal: (-0.15, -0.09, 0.16), steps: 50
#  truncated. goal: (-0.15, -0.09, 0.18), steps: 50
#  truncated. goal: (-0.15, -0.09, 0.2), steps: 50
#  success. goal: (-0.15, -0.09, 0.22), steps: 9
#  success. goal: (-0.15, -0.09, 0.24), steps: 8
#  success. goal: (-0.15, -0.09, 0.26), steps: 7
#  success. goal: (-0.15, -0.09, 0.28), steps: 8
#  truncated. goal: (-0.15, -0.09, 0.3), steps: 50
#  truncated. goal: (-0.15, -0.07, 0.0), steps: 50
#  truncated. goal: (-0.15, -0.07, 0.02), steps: 50
#  truncated. goal: (-0.15, -0.07, 0.04), steps: 50
#  truncated. goal: (-0.15, -0.07, 0.06), steps: 50
#  truncated. goal: (-0.15, -0.07, 0.08), steps: 50
#  truncated. goal: (-0.15, -0.07, 0.1), steps: 50
#  truncated. goal: (-0.15, -0.07, 0.12), steps: 50
#  truncated. goal: (-0.15, -0.07, 0.14), steps: 50
#  truncated. goal: (-0.15, -0.07, 0.16), steps: 50
#  truncated. goal: (-0.15, -0.07, 0.18), steps: 50
#  truncated. goal: (-0.15, -0.07, 0.2), steps: 50
#  truncated. goal: (-0.15, -0.07, 0.22), steps: 50
#  truncated. goal: (-0.15, -0.07, 0.24), steps: 50
#  truncated. goal: (-0.15, -0.07, 0.26), steps: 50
#  truncated. goal: (-0.15, -0.07, 0.28), steps: 50
#  truncated. goal: (-0.15, -0.07, 0.3), steps: 50
#  truncated. goal: (-0.15, -0.05, 0.0), steps: 50
#  truncated. goal: (-0.15, -0.05, 0.02), steps: 50
#  truncated. goal: (-0.15, -0.05, 0.04), steps: 50
#  truncated. goal: (-0.15, -0.05, 0.06), steps: 50
#  truncated. goal: (-0.15, -0.05, 0.08), steps: 50
#  truncated. goal: (-0.15, -0.05, 0.1), steps: 50
#  truncated. goal: (-0.15, -0.05, 0.12), steps: 50
#  truncated. goal: (-0.15, -0.05, 0.14), steps: 50
#  truncated. goal: (-0.15, -0.05, 0.16), steps: 50
#  truncated. goal: (-0.15, -0.05, 0.18), steps: 50
#  truncated. goal: (-0.15, -0.05, 0.2), steps: 50
#  truncated. goal: (-0.15, -0.05, 0.22), steps: 50
#  truncated. goal: (-0.15, -0.05, 0.24), steps: 50
#  truncated. goal: (-0.15, -0.05, 0.26), steps: 50
#  truncated. goal: (-0.15, -0.05, 0.28), steps: 50
#  truncated. goal: (-0.15, -0.05, 0.3), steps: 50
#  truncated. goal: (-0.15, -0.03, 0.0), steps: 50
#  truncated. goal: (-0.15, -0.03, 0.02), steps: 50
#  truncated. goal: (-0.15, -0.03, 0.04), steps: 50
#  truncated. goal: (-0.15, -0.03, 0.06), steps: 50
#  truncated. goal: (-0.15, -0.03, 0.08), steps: 50
#  truncated. goal: (-0.15, -0.03, 0.1), steps: 50
#  truncated. goal: (-0.15, -0.03, 0.12), steps: 50
#  truncated. goal: (-0.15, -0.03, 0.14), steps: 50
#  truncated. goal: (-0.15, -0.03, 0.16), steps: 50
#  truncated. goal: (-0.15, -0.03, 0.18), steps: 50
#  truncated. goal: (-0.15, -0.03, 0.2), steps: 50
#  truncated. goal: (-0.15, -0.03, 0.22), steps: 50
#  truncated. goal: (-0.15, -0.03, 0.24), steps: 50
#  truncated. goal: (-0.15, -0.03, 0.26), steps: 50
#  truncated. goal: (-0.15, -0.03, 0.28), steps: 50
#  truncated. goal: (-0.15, -0.03, 0.3), steps: 50
#  truncated. goal: (-0.15, -0.01, 0.0), steps: 50
#  truncated. goal: (-0.15, -0.01, 0.02), steps: 50
#  success. goal: (-0.15, -0.01, 0.04), steps: 6
#  success. goal: (-0.15, -0.01, 0.06), steps: 6
#  truncated. goal: (-0.15, -0.01, 0.08), steps: 50
#  truncated. goal: (-0.15, -0.01, 0.1), steps: 50
#  truncated. goal: (-0.15, -0.01, 0.12), steps: 50
#  truncated. goal: (-0.15, -0.01, 0.14), steps: 50
#  success. goal: (-0.15, -0.01, 0.16), steps: 7
#  truncated. goal: (-0.15, -0.01, 0.18), steps: 50
#  truncated. goal: (-0.15, -0.01, 0.2), steps: 50
#  truncated. goal: (-0.15, -0.01, 0.22), steps: 50
#  truncated. goal: (-0.15, -0.01, 0.24), steps: 50
#  truncated. goal: (-0.15, -0.01, 0.26), steps: 50
#  truncated. goal: (-0.15, -0.01, 0.28), steps: 50
#  truncated. goal: (-0.15, -0.01, 0.3), steps: 50
#  truncated. goal: (-0.15, 0.01, 0.0), steps: 50
#  truncated. goal: (-0.15, 0.01, 0.02), steps: 50
#  success. goal: (-0.15, 0.01, 0.04), steps: 6
#  success. goal: (-0.15, 0.01, 0.06), steps: 6
#  success. goal: (-0.15, 0.01, 0.08), steps: 6
#  truncated. goal: (-0.15, 0.01, 0.1), steps: 50
#  truncated. goal: (-0.15, 0.01, 0.12), steps: 50
#  success. goal: (-0.15, 0.01, 0.14), steps: 7
#  success. goal: (-0.15, 0.01, 0.16), steps: 7
#  success. goal: (-0.15, 0.01, 0.18), steps: 7
#  success. goal: (-0.15, 0.01, 0.2), steps: 7
#  truncated. goal: (-0.15, 0.01, 0.22), steps: 50
#  success. goal: (-0.15, 0.01, 0.24), steps: 7
#  success. goal: (-0.15, 0.01, 0.26), steps: 7
#  truncated. goal: (-0.15, 0.01, 0.28), steps: 50
#  truncated. goal: (-0.15, 0.01, 0.3), steps: 50
#  truncated. goal: (-0.15, 0.03, 0.0), steps: 50
#  success. goal: (-0.15, 0.03, 0.02), steps: 6
#  success. goal: (-0.15, 0.03, 0.04), steps: 6
#  success. goal: (-0.15, 0.03, 0.06), steps: 6
#  success. goal: (-0.15, 0.03, 0.08), steps: 6
#  success. goal: (-0.15, 0.03, 0.1), steps: 6
#  success. goal: (-0.15, 0.03, 0.12), steps: 7
#  success. goal: (-0.15, 0.03, 0.14), steps: 6
#  success. goal: (-0.15, 0.03, 0.16), steps: 7
#  success. goal: (-0.15, 0.03, 0.18), steps: 7
#  success. goal: (-0.15, 0.03, 0.2), steps: 7
#  success. goal: (-0.15, 0.03, 0.22), steps: 6
#  success. goal: (-0.15, 0.03, 0.24), steps: 6
#  success. goal: (-0.15, 0.03, 0.26), steps: 6
#  success. goal: (-0.15, 0.03, 0.28), steps: 7
#  truncated. goal: (-0.15, 0.03, 0.3), steps: 50
#  truncated. goal: (-0.15, 0.05, 0.0), steps: 50
#  truncated. goal: (-0.15, 0.05, 0.02), steps: 50
#  success. goal: (-0.15, 0.05, 0.04), steps: 6
#  success. goal: (-0.15, 0.05, 0.06), steps: 6
#  success. goal: (-0.15, 0.05, 0.08), steps: 6
#  success. goal: (-0.15, 0.05, 0.1), steps: 6
#  success. goal: (-0.15, 0.05, 0.12), steps: 6
#  success. goal: (-0.15, 0.05, 0.14), steps: 6
#  success. goal: (-0.15, 0.05, 0.16), steps: 6
#  success. goal: (-0.15, 0.05, 0.18), steps: 6
#  success. goal: (-0.15, 0.05, 0.2), steps: 6
#  success. goal: (-0.15, 0.05, 0.22), steps: 6
#  success. goal: (-0.15, 0.05, 0.24), steps: 6
#  success. goal: (-0.15, 0.05, 0.26), steps: 7
#  success. goal: (-0.15, 0.05, 0.28), steps: 7
#  success. goal: (-0.15, 0.05, 0.3), steps: 8
#  truncated. goal: (-0.15, 0.07, 0.0), steps: 50
#  truncated. goal: (-0.15, 0.07, 0.02), steps: 50
#  truncated. goal: (-0.15, 0.07, 0.04), steps: 50
#  truncated. goal: (-0.15, 0.07, 0.06), steps: 50
#  truncated. goal: (-0.15, 0.07, 0.08), steps: 50
#  success. goal: (-0.15, 0.07, 0.1), steps: 6
#  success. goal: (-0.15, 0.07, 0.12), steps: 6
#  success. goal: (-0.15, 0.07, 0.14), steps: 6
#  success. goal: (-0.15, 0.07, 0.16), steps: 6
#  success. goal: (-0.15, 0.07, 0.18), steps: 6
#  success. goal: (-0.15, 0.07, 0.2), steps: 7
#  success. goal: (-0.15, 0.07, 0.22), steps: 6
#  success. goal: (-0.15, 0.07, 0.24), steps: 6
#  success. goal: (-0.15, 0.07, 0.26), steps: 7
#  success. goal: (-0.15, 0.07, 0.28), steps: 7
#  success. goal: (-0.15, 0.07, 0.3), steps: 8
#  truncated. goal: (-0.15, 0.09, 0.0), steps: 50
#  success. goal: (-0.15, 0.09, 0.02), steps: 6
#  success. goal: (-0.15, 0.09, 0.04), steps: 6
#  truncated. goal: (-0.15, 0.09, 0.06), steps: 50
#  success. goal: (-0.15, 0.09, 0.08), steps: 21
#  success. goal: (-0.15, 0.09, 0.1), steps: 20
#  success. goal: (-0.15, 0.09, 0.12), steps: 6
#  success. goal: (-0.15, 0.09, 0.14), steps: 6
#  success. goal: (-0.15, 0.09, 0.16), steps: 6
#  success. goal: (-0.15, 0.09, 0.18), steps: 6
#  success. goal: (-0.15, 0.09, 0.2), steps: 6
#  success. goal: (-0.15, 0.09, 0.22), steps: 6
#  success. goal: (-0.15, 0.09, 0.24), steps: 7
#  success. goal: (-0.15, 0.09, 0.26), steps: 7
#  success. goal: (-0.15, 0.09, 0.28), steps: 7
#  success. goal: (-0.15, 0.09, 0.3), steps: 8
#  truncated. goal: (-0.15, 0.11, 0.0), steps: 50
#  truncated. goal: (-0.15, 0.11, 0.02), steps: 50
#  truncated. goal: (-0.15, 0.11, 0.04), steps: 50
#  truncated. goal: (-0.15, 0.11, 0.06), steps: 50
#  success. goal: (-0.15, 0.11, 0.08), steps: 21
#  success. goal: (-0.15, 0.11, 0.1), steps: 22
#  success. goal: (-0.15, 0.11, 0.12), steps: 6
#  success. goal: (-0.15, 0.11, 0.14), steps: 6
#  success. goal: (-0.15, 0.11, 0.16), steps: 6
#  success. goal: (-0.15, 0.11, 0.18), steps: 6
#  success. goal: (-0.15, 0.11, 0.2), steps: 6
#  success. goal: (-0.15, 0.11, 0.22), steps: 7
#  success. goal: (-0.15, 0.11, 0.24), steps: 7
#  success. goal: (-0.15, 0.11, 0.26), steps: 7
#  success. goal: (-0.15, 0.11, 0.28), steps: 8
#  success. goal: (-0.15, 0.11, 0.3), steps: 8
#  truncated. goal: (-0.15, 0.13, 0.0), steps: 50
#  truncated. goal: (-0.15, 0.13, 0.02), steps: 50
#  success. goal: (-0.15, 0.13, 0.04), steps: 6
#  success. goal: (-0.15, 0.13, 0.06), steps: 6
#  success. goal: (-0.15, 0.13, 0.08), steps: 6
#  success. goal: (-0.15, 0.13, 0.1), steps: 6
#  success. goal: (-0.15, 0.13, 0.12), steps: 6
#  success. goal: (-0.15, 0.13, 0.14), steps: 6
#  success. goal: (-0.15, 0.13, 0.16), steps: 6
#  success. goal: (-0.15, 0.13, 0.18), steps: 6
#  success. goal: (-0.15, 0.13, 0.2), steps: 7
#  success. goal: (-0.15, 0.13, 0.22), steps: 7
#  success. goal: (-0.15, 0.13, 0.24), steps: 8
#  success. goal: (-0.15, 0.13, 0.26), steps: 8
#  success. goal: (-0.15, 0.13, 0.28), steps: 9
#  success. goal: (-0.15, 0.13, 0.3), steps: 9
#  truncated. goal: (-0.15, 0.15, 0.0), steps: 50
#  truncated. goal: (-0.15, 0.15, 0.02), steps: 50
#  success. goal: (-0.15, 0.15, 0.04), steps: 6
#  success. goal: (-0.15, 0.15, 0.06), steps: 6
#  success. goal: (-0.15, 0.15, 0.08), steps: 6
#  success. goal: (-0.15, 0.15, 0.1), steps: 6
#  success. goal: (-0.15, 0.15, 0.12), steps: 6
#  success. goal: (-0.15, 0.15, 0.14), steps: 6
#  success. goal: (-0.15, 0.15, 0.16), steps: 6
#  success. goal: (-0.15, 0.15, 0.18), steps: 7
#  success. goal: (-0.15, 0.15, 0.2), steps: 7
#  success. goal: (-0.15, 0.15, 0.22), steps: 7
#  success. goal: (-0.15, 0.15, 0.24), steps: 8
#  success. goal: (-0.15, 0.15, 0.26), steps: 9
#  success. goal: (-0.15, 0.15, 0.28), steps: 9
#  success. goal: (-0.15, 0.15, 0.3), steps: 11
#  truncated. goal: (-0.13, -0.15, 0.0), steps: 50
#  truncated. goal: (-0.13, -0.15, 0.02), steps: 50
#  truncated. goal: (-0.13, -0.15, 0.04), steps: 50
#  truncated. goal: (-0.13, -0.15, 0.06), steps: 50
#  truncated. goal: (-0.13, -0.15, 0.08), steps: 50
#  truncated. goal: (-0.13, -0.15, 0.1), steps: 50
#  success. goal: (-0.13, -0.15, 0.12), steps: 10
#  success. goal: (-0.13, -0.15, 0.14), steps: 10
#  success. goal: (-0.13, -0.15, 0.16), steps: 10
#  success. goal: (-0.13, -0.15, 0.18), steps: 10
#  success. goal: (-0.13, -0.15, 0.2), steps: 7
#  success. goal: (-0.13, -0.15, 0.22), steps: 9
#  success. goal: (-0.13, -0.15, 0.24), steps: 9
#  success. goal: (-0.13, -0.15, 0.26), steps: 9
#  success. goal: (-0.13, -0.15, 0.28), steps: 9
#  truncated. goal: (-0.13, -0.15, 0.3), steps: 50
#  truncated. goal: (-0.13, -0.13, 0.0), steps: 50
#  truncated. goal: (-0.13, -0.13, 0.02), steps: 50
#  truncated. goal: (-0.13, -0.13, 0.04), steps: 50
#  truncated. goal: (-0.13, -0.13, 0.06), steps: 50
#  truncated. goal: (-0.13, -0.13, 0.08), steps: 50
#  truncated. goal: (-0.13, -0.13, 0.1), steps: 50
#  truncated. goal: (-0.13, -0.13, 0.12), steps: 50
#  truncated. goal: (-0.13, -0.13, 0.14), steps: 50
#  truncated. goal: (-0.13, -0.13, 0.16), steps: 50
#  success. goal: (-0.13, -0.13, 0.18), steps: 10
#  success. goal: (-0.13, -0.13, 0.2), steps: 7
#  success. goal: (-0.13, -0.13, 0.22), steps: 7
#  success. goal: (-0.13, -0.13, 0.24), steps: 7
#  success. goal: (-0.13, -0.13, 0.26), steps: 8
#  success. goal: (-0.13, -0.13, 0.28), steps: 8
#  success. goal: (-0.13, -0.13, 0.3), steps: 8
#  truncated. goal: (-0.13, -0.11, 0.0), steps: 50
#  truncated. goal: (-0.13, -0.11, 0.02), steps: 50
#  truncated. goal: (-0.13, -0.11, 0.04), steps: 50
#  truncated. goal: (-0.13, -0.11, 0.06), steps: 50
#  truncated. goal: (-0.13, -0.11, 0.08), steps: 50
#  truncated. goal: (-0.13, -0.11, 0.1), steps: 50
#  truncated. goal: (-0.13, -0.11, 0.12), steps: 50
#  truncated. goal: (-0.13, -0.11, 0.14), steps: 50
#  truncated. goal: (-0.13, -0.11, 0.16), steps: 50
#  truncated. goal: (-0.13, -0.11, 0.18), steps: 50
#  success. goal: (-0.13, -0.11, 0.2), steps: 7
#  success. goal: (-0.13, -0.11, 0.22), steps: 7
#  success. goal: (-0.13, -0.11, 0.24), steps: 6
#  success. goal: (-0.13, -0.11, 0.26), steps: 7
#  success. goal: (-0.13, -0.11, 0.28), steps: 7
#  success. goal: (-0.13, -0.11, 0.3), steps: 8
#  truncated. goal: (-0.13, -0.09, 0.0), steps: 50
#  truncated. goal: (-0.13, -0.09, 0.02), steps: 50
#  truncated. goal: (-0.13, -0.09, 0.04), steps: 50
#  truncated. goal: (-0.13, -0.09, 0.06), steps: 50
#  truncated. goal: (-0.13, -0.09, 0.08), steps: 50
#  truncated. goal: (-0.13, -0.09, 0.1), steps: 50
#  truncated. goal: (-0.13, -0.09, 0.12), steps: 50
#  truncated. goal: (-0.13, -0.09, 0.14), steps: 50
#  truncated. goal: (-0.13, -0.09, 0.16), steps: 50
#  truncated. goal: (-0.13, -0.09, 0.18), steps: 50
#  truncated. goal: (-0.13, -0.09, 0.2), steps: 50
#  success. goal: (-0.13, -0.09, 0.22), steps: 9
#  success. goal: (-0.13, -0.09, 0.24), steps: 6
#  success. goal: (-0.13, -0.09, 0.26), steps: 6
#  truncated. goal: (-0.13, -0.09, 0.28), steps: 50
#  truncated. goal: (-0.13, -0.09, 0.3), steps: 50
#  truncated. goal: (-0.13, -0.07, 0.0), steps: 50
#  truncated. goal: (-0.13, -0.07, 0.02), steps: 50
#  truncated. goal: (-0.13, -0.07, 0.04), steps: 50
#  truncated. goal: (-0.13, -0.07, 0.06), steps: 50
#  truncated. goal: (-0.13, -0.07, 0.08), steps: 50
#  truncated. goal: (-0.13, -0.07, 0.1), steps: 50
#  truncated. goal: (-0.13, -0.07, 0.12), steps: 50
#  truncated. goal: (-0.13, -0.07, 0.14), steps: 50
#  truncated. goal: (-0.13, -0.07, 0.16), steps: 50
#  truncated. goal: (-0.13, -0.07, 0.18), steps: 50
#  truncated. goal: (-0.13, -0.07, 0.2), steps: 50
#  truncated. goal: (-0.13, -0.07, 0.22), steps: 50
#  truncated. goal: (-0.13, -0.07, 0.24), steps: 50
#  truncated. goal: (-0.13, -0.07, 0.26), steps: 50
#  truncated. goal: (-0.13, -0.07, 0.28), steps: 50
#  success. goal: (-0.13, -0.07, 0.3), steps: 7
#  truncated. goal: (-0.13, -0.05, 0.0), steps: 50
#  truncated. goal: (-0.13, -0.05, 0.02), steps: 50
#  truncated. goal: (-0.13, -0.05, 0.04), steps: 50
#  truncated. goal: (-0.13, -0.05, 0.06), steps: 50
#  truncated. goal: (-0.13, -0.05, 0.08), steps: 50
#  truncated. goal: (-0.13, -0.05, 0.1), steps: 50
#  truncated. goal: (-0.13, -0.05, 0.12), steps: 50
#  truncated. goal: (-0.13, -0.05, 0.14), steps: 50
#  truncated. goal: (-0.13, -0.05, 0.16), steps: 50
#  truncated. goal: (-0.13, -0.05, 0.18), steps: 50
#  truncated. goal: (-0.13, -0.05, 0.2), steps: 50
#  truncated. goal: (-0.13, -0.05, 0.22), steps: 50
#  truncated. goal: (-0.13, -0.05, 0.24), steps: 50
#  truncated. goal: (-0.13, -0.05, 0.26), steps: 50
#  success. goal: (-0.13, -0.05, 0.28), steps: 6
#  success. goal: (-0.13, -0.05, 0.3), steps: 7
#  truncated. goal: (-0.13, -0.03, 0.0), steps: 50
#  truncated. goal: (-0.13, -0.03, 0.02), steps: 50
#  truncated. goal: (-0.13, -0.03, 0.04), steps: 50
#  truncated. goal: (-0.13, -0.03, 0.06), steps: 50
#  truncated. goal: (-0.13, -0.03, 0.08), steps: 50
#  truncated. goal: (-0.13, -0.03, 0.1), steps: 50
#  truncated. goal: (-0.13, -0.03, 0.12), steps: 50
#  truncated. goal: (-0.13, -0.03, 0.14), steps: 50
#  truncated. goal: (-0.13, -0.03, 0.16), steps: 50
#  truncated. goal: (-0.13, -0.03, 0.18), steps: 50
#  truncated. goal: (-0.13, -0.03, 0.2), steps: 50
#  truncated. goal: (-0.13, -0.03, 0.22), steps: 50
#  truncated. goal: (-0.13, -0.03, 0.24), steps: 50
#  truncated. goal: (-0.13, -0.03, 0.26), steps: 50
#  success. goal: (-0.13, -0.03, 0.28), steps: 6
#  success. goal: (-0.13, -0.03, 0.3), steps: 7
#  truncated. goal: (-0.13, -0.01, 0.0), steps: 50
#  truncated. goal: (-0.13, -0.01, 0.02), steps: 50
#  truncated. goal: (-0.13, -0.01, 0.04), steps: 50
#  truncated. goal: (-0.13, -0.01, 0.06), steps: 50
#  success. goal: (-0.13, -0.01, 0.08), steps: 6
#  truncated. goal: (-0.13, -0.01, 0.1), steps: 50
#  truncated. goal: (-0.13, -0.01, 0.12), steps: 50
#  truncated. goal: (-0.13, -0.01, 0.14), steps: 50
#  truncated. goal: (-0.13, -0.01, 0.16), steps: 50
#  truncated. goal: (-0.13, -0.01, 0.18), steps: 50
#  truncated. goal: (-0.13, -0.01, 0.2), steps: 50
#  truncated. goal: (-0.13, -0.01, 0.22), steps: 50
#  truncated. goal: (-0.13, -0.01, 0.24), steps: 50
#  truncated. goal: (-0.13, -0.01, 0.26), steps: 50
#  success. goal: (-0.13, -0.01, 0.28), steps: 7
#  success. goal: (-0.13, -0.01, 0.3), steps: 7
#  truncated. goal: (-0.13, 0.01, 0.0), steps: 50
#  truncated. goal: (-0.13, 0.01, 0.02), steps: 50
#  truncated. goal: (-0.13, 0.01, 0.04), steps: 50
#  success. goal: (-0.13, 0.01, 0.06), steps: 5
#  success. goal: (-0.13, 0.01, 0.08), steps: 5
#  success. goal: (-0.13, 0.01, 0.1), steps: 6
#  success. goal: (-0.13, 0.01, 0.12), steps: 6
#  success. goal: (-0.13, 0.01, 0.14), steps: 6
#  success. goal: (-0.13, 0.01, 0.16), steps: 6
#  success. goal: (-0.13, 0.01, 0.18), steps: 6
#  truncated. goal: (-0.13, 0.01, 0.2), steps: 50
#  truncated. goal: (-0.13, 0.01, 0.22), steps: 50
#  truncated. goal: (-0.13, 0.01, 0.24), steps: 50
#  truncated. goal: (-0.13, 0.01, 0.26), steps: 50
#  truncated. goal: (-0.13, 0.01, 0.28), steps: 50
#  truncated. goal: (-0.13, 0.01, 0.3), steps: 50
#  truncated. goal: (-0.13, 0.03, 0.0), steps: 50
#  truncated. goal: (-0.13, 0.03, 0.02), steps: 50
#  truncated. goal: (-0.13, 0.03, 0.04), steps: 50
#  success. goal: (-0.13, 0.03, 0.06), steps: 5
#  success. goal: (-0.13, 0.03, 0.08), steps: 5
#  success. goal: (-0.13, 0.03, 0.1), steps: 5
#  success. goal: (-0.13, 0.03, 0.12), steps: 6
#  success. goal: (-0.13, 0.03, 0.14), steps: 6
#  success. goal: (-0.13, 0.03, 0.16), steps: 6
#  success. goal: (-0.13, 0.03, 0.18), steps: 6
#  success. goal: (-0.13, 0.03, 0.2), steps: 6
#  success. goal: (-0.13, 0.03, 0.22), steps: 6
#  success. goal: (-0.13, 0.03, 0.24), steps: 6
#  success. goal: (-0.13, 0.03, 0.26), steps: 6
#  truncated. goal: (-0.13, 0.03, 0.28), steps: 50
#  truncated. goal: (-0.13, 0.03, 0.3), steps: 50
#  truncated. goal: (-0.13, 0.05, 0.0), steps: 50
#  truncated. goal: (-0.13, 0.05, 0.02), steps: 50
#  truncated. goal: (-0.13, 0.05, 0.04), steps: 50
#  success. goal: (-0.13, 0.05, 0.06), steps: 5
#  success. goal: (-0.13, 0.05, 0.08), steps: 5
#  success. goal: (-0.13, 0.05, 0.1), steps: 5
#  success. goal: (-0.13, 0.05, 0.12), steps: 5
#  success. goal: (-0.13, 0.05, 0.14), steps: 6
#  success. goal: (-0.13, 0.05, 0.16), steps: 6
#  success. goal: (-0.13, 0.05, 0.18), steps: 6
#  success. goal: (-0.13, 0.05, 0.2), steps: 6
#  success. goal: (-0.13, 0.05, 0.22), steps: 6
#  success. goal: (-0.13, 0.05, 0.24), steps: 6
#  success. goal: (-0.13, 0.05, 0.26), steps: 6
#  truncated. goal: (-0.13, 0.05, 0.28), steps: 50
#  truncated. goal: (-0.13, 0.05, 0.3), steps: 50
#  truncated. goal: (-0.13, 0.07, 0.0), steps: 50
#  truncated. goal: (-0.13, 0.07, 0.02), steps: 50
#  truncated. goal: (-0.13, 0.07, 0.04), steps: 50
#  success. goal: (-0.13, 0.07, 0.06), steps: 5
#  success. goal: (-0.13, 0.07, 0.08), steps: 5
#  success. goal: (-0.13, 0.07, 0.1), steps: 5
#  success. goal: (-0.13, 0.07, 0.12), steps: 5
#  success. goal: (-0.13, 0.07, 0.14), steps: 5
#  success. goal: (-0.13, 0.07, 0.16), steps: 6
#  success. goal: (-0.13, 0.07, 0.18), steps: 6
#  success. goal: (-0.13, 0.07, 0.2), steps: 6
#  success. goal: (-0.13, 0.07, 0.22), steps: 6
#  success. goal: (-0.13, 0.07, 0.24), steps: 6
#  success. goal: (-0.13, 0.07, 0.26), steps: 6
#  truncated. goal: (-0.13, 0.07, 0.28), steps: 50
#  truncated. goal: (-0.13, 0.07, 0.3), steps: 50
#  truncated. goal: (-0.13, 0.09, 0.0), steps: 50
#  truncated. goal: (-0.13, 0.09, 0.02), steps: 50
#  success. goal: (-0.13, 0.09, 0.04), steps: 5
#  success. goal: (-0.13, 0.09, 0.06), steps: 5
#  success. goal: (-0.13, 0.09, 0.08), steps: 5
#  success. goal: (-0.13, 0.09, 0.1), steps: 5
#  success. goal: (-0.13, 0.09, 0.12), steps: 5
#  success. goal: (-0.13, 0.09, 0.14), steps: 5
#  success. goal: (-0.13, 0.09, 0.16), steps: 5
#  success. goal: (-0.13, 0.09, 0.18), steps: 6
#  success. goal: (-0.13, 0.09, 0.2), steps: 6
#  success. goal: (-0.13, 0.09, 0.22), steps: 6
#  success. goal: (-0.13, 0.09, 0.24), steps: 6
#  success. goal: (-0.13, 0.09, 0.26), steps: 7
#  success. goal: (-0.13, 0.09, 0.28), steps: 7
#  truncated. goal: (-0.13, 0.09, 0.3), steps: 50
#  truncated. goal: (-0.13, 0.11, 0.0), steps: 50
#  truncated. goal: (-0.13, 0.11, 0.02), steps: 50
#  truncated. goal: (-0.13, 0.11, 0.04), steps: 50
#  success. goal: (-0.13, 0.11, 0.06), steps: 5
#  success. goal: (-0.13, 0.11, 0.08), steps: 5
#  success. goal: (-0.13, 0.11, 0.1), steps: 5
#  success. goal: (-0.13, 0.11, 0.12), steps: 6
#  success. goal: (-0.13, 0.11, 0.14), steps: 5
#  truncated. goal: (-0.13, 0.11, 0.16), steps: 50
#  success. goal: (-0.13, 0.11, 0.18), steps: 6
#  success. goal: (-0.13, 0.11, 0.2), steps: 6
#  success. goal: (-0.13, 0.11, 0.22), steps: 6
#  success. goal: (-0.13, 0.11, 0.24), steps: 7
#  success. goal: (-0.13, 0.11, 0.26), steps: 7
#  success. goal: (-0.13, 0.11, 0.28), steps: 8
#  truncated. goal: (-0.13, 0.11, 0.3), steps: 50
#  truncated. goal: (-0.13, 0.13, 0.0), steps: 50
#  success. goal: (-0.13, 0.13, 0.02), steps: 6
#  success. goal: (-0.13, 0.13, 0.04), steps: 6
#  success. goal: (-0.13, 0.13, 0.06), steps: 6
#  success. goal: (-0.13, 0.13, 0.08), steps: 6
#  success. goal: (-0.13, 0.13, 0.1), steps: 30
#  truncated. goal: (-0.13, 0.13, 0.12), steps: 50
#  truncated. goal: (-0.13, 0.13, 0.14), steps: 50
#  success. goal: (-0.13, 0.13, 0.16), steps: 6
#  success. goal: (-0.13, 0.13, 0.18), steps: 6
#  success. goal: (-0.13, 0.13, 0.2), steps: 7
#  success. goal: (-0.13, 0.13, 0.22), steps: 7
#  success. goal: (-0.13, 0.13, 0.24), steps: 8
#  success. goal: (-0.13, 0.13, 0.26), steps: 8
#  success. goal: (-0.13, 0.13, 0.28), steps: 9
#  truncated. goal: (-0.13, 0.13, 0.3), steps: 50
#  truncated. goal: (-0.13, 0.15, 0.0), steps: 50
#  success. goal: (-0.13, 0.15, 0.02), steps: 28
#  success. goal: (-0.13, 0.15, 0.04), steps: 6
#  success. goal: (-0.13, 0.15, 0.06), steps: 6
#  success. goal: (-0.13, 0.15, 0.08), steps: 6
#  truncated. goal: (-0.13, 0.15, 0.1), steps: 50
#  truncated. goal: (-0.13, 0.15, 0.12), steps: 50
#  success. goal: (-0.13, 0.15, 0.14), steps: 6
#  success. goal: (-0.13, 0.15, 0.16), steps: 6
#  success. goal: (-0.13, 0.15, 0.18), steps: 7
#  success. goal: (-0.13, 0.15, 0.2), steps: 7
#  success. goal: (-0.13, 0.15, 0.22), steps: 8
#  success. goal: (-0.13, 0.15, 0.24), steps: 8
#  success. goal: (-0.13, 0.15, 0.26), steps: 9
#  success. goal: (-0.13, 0.15, 0.28), steps: 9
#  truncated. goal: (-0.13, 0.15, 0.3), steps: 50
#  truncated. goal: (-0.11, -0.15, 0.0), steps: 50
#  truncated. goal: (-0.11, -0.15, 0.02), steps: 50
#  truncated. goal: (-0.11, -0.15, 0.04), steps: 50
#  truncated. goal: (-0.11, -0.15, 0.06), steps: 50
#  truncated. goal: (-0.11, -0.15, 0.08), steps: 50
#  truncated. goal: (-0.11, -0.15, 0.1), steps: 50
#  success. goal: (-0.11, -0.15, 0.12), steps: 9
#  success. goal: (-0.11, -0.15, 0.14), steps: 9
#  success. goal: (-0.11, -0.15, 0.16), steps: 9
#  success. goal: (-0.11, -0.15, 0.18), steps: 9
#  success. goal: (-0.11, -0.15, 0.2), steps: 9
#  success. goal: (-0.11, -0.15, 0.22), steps: 6
#  success. goal: (-0.11, -0.15, 0.24), steps: 7
#  success. goal: (-0.11, -0.15, 0.26), steps: 9
#  success. goal: (-0.11, -0.15, 0.28), steps: 9
#  success. goal: (-0.11, -0.15, 0.3), steps: 8
#  truncated. goal: (-0.11, -0.13, 0.0), steps: 50
#  truncated. goal: (-0.11, -0.13, 0.02), steps: 50
#  truncated. goal: (-0.11, -0.13, 0.04), steps: 50
#  truncated. goal: (-0.11, -0.13, 0.06), steps: 50
#  truncated. goal: (-0.11, -0.13, 0.08), steps: 50
#  truncated. goal: (-0.11, -0.13, 0.1), steps: 50
#  truncated. goal: (-0.11, -0.13, 0.12), steps: 50
#  success. goal: (-0.11, -0.13, 0.14), steps: 10
#  success. goal: (-0.11, -0.13, 0.16), steps: 9
#  success. goal: (-0.11, -0.13, 0.18), steps: 9
#  success. goal: (-0.11, -0.13, 0.2), steps: 6
#  success. goal: (-0.11, -0.13, 0.22), steps: 6
#  success. goal: (-0.11, -0.13, 0.24), steps: 6
#  success. goal: (-0.11, -0.13, 0.26), steps: 8
#  success. goal: (-0.11, -0.13, 0.28), steps: 8
#  success. goal: (-0.11, -0.13, 0.3), steps: 8
#  truncated. goal: (-0.11, -0.11, 0.0), steps: 50
#  truncated. goal: (-0.11, -0.11, 0.02), steps: 50
#  truncated. goal: (-0.11, -0.11, 0.04), steps: 50
#  truncated. goal: (-0.11, -0.11, 0.06), steps: 50
#  truncated. goal: (-0.11, -0.11, 0.08), steps: 50
#  truncated. goal: (-0.11, -0.11, 0.1), steps: 50
#  truncated. goal: (-0.11, -0.11, 0.12), steps: 50
#  truncated. goal: (-0.11, -0.11, 0.14), steps: 50
#  truncated. goal: (-0.11, -0.11, 0.16), steps: 50
#  success. goal: (-0.11, -0.11, 0.18), steps: 9
#  success. goal: (-0.11, -0.11, 0.2), steps: 9
#  success. goal: (-0.11, -0.11, 0.22), steps: 7
#  success. goal: (-0.11, -0.11, 0.24), steps: 6
#  success. goal: (-0.11, -0.11, 0.26), steps: 6
#  success. goal: (-0.11, -0.11, 0.28), steps: 7
#  truncated. goal: (-0.11, -0.11, 0.3), steps: 50
#  truncated. goal: (-0.11, -0.09, 0.0), steps: 50
#  truncated. goal: (-0.11, -0.09, 0.02), steps: 50
#  truncated. goal: (-0.11, -0.09, 0.04), steps: 50
#  truncated. goal: (-0.11, -0.09, 0.06), steps: 50
#  truncated. goal: (-0.11, -0.09, 0.08), steps: 50
#  truncated. goal: (-0.11, -0.09, 0.1), steps: 50
#  truncated. goal: (-0.11, -0.09, 0.12), steps: 50
#  truncated. goal: (-0.11, -0.09, 0.14), steps: 50
#  truncated. goal: (-0.11, -0.09, 0.16), steps: 50
#  truncated. goal: (-0.11, -0.09, 0.18), steps: 50
#  success. goal: (-0.11, -0.09, 0.2), steps: 8
#  success. goal: (-0.11, -0.09, 0.22), steps: 6
#  success. goal: (-0.11, -0.09, 0.24), steps: 6
#  success. goal: (-0.11, -0.09, 0.26), steps: 6
#  success. goal: (-0.11, -0.09, 0.28), steps: 6
#  truncated. goal: (-0.11, -0.09, 0.3), steps: 50
#  truncated. goal: (-0.11, -0.07, 0.0), steps: 50
#  truncated. goal: (-0.11, -0.07, 0.02), steps: 50
#  truncated. goal: (-0.11, -0.07, 0.04), steps: 50
#  truncated. goal: (-0.11, -0.07, 0.06), steps: 50
#  truncated. goal: (-0.11, -0.07, 0.08), steps: 50
#  truncated. goal: (-0.11, -0.07, 0.1), steps: 50
#  truncated. goal: (-0.11, -0.07, 0.12), steps: 50
#  truncated. goal: (-0.11, -0.07, 0.14), steps: 50
#  truncated. goal: (-0.11, -0.07, 0.16), steps: 50
#  truncated. goal: (-0.11, -0.07, 0.18), steps: 50
#  truncated. goal: (-0.11, -0.07, 0.2), steps: 50
#  success. goal: (-0.11, -0.07, 0.22), steps: 8
#  success. goal: (-0.11, -0.07, 0.24), steps: 8
#  success. goal: (-0.11, -0.07, 0.26), steps: 16
#  success. goal: (-0.11, -0.07, 0.28), steps: 6
#  success. goal: (-0.11, -0.07, 0.3), steps: 7
#  truncated. goal: (-0.11, -0.05, 0.0), steps: 50
#  truncated. goal: (-0.11, -0.05, 0.02), steps: 50
#  truncated. goal: (-0.11, -0.05, 0.04), steps: 50
#  truncated. goal: (-0.11, -0.05, 0.06), steps: 50
#  truncated. goal: (-0.11, -0.05, 0.08), steps: 50
#  truncated. goal: (-0.11, -0.05, 0.1), steps: 50
#  truncated. goal: (-0.11, -0.05, 0.12), steps: 50
#  truncated. goal: (-0.11, -0.05, 0.14), steps: 50
#  truncated. goal: (-0.11, -0.05, 0.16), steps: 50
#  truncated. goal: (-0.11, -0.05, 0.18), steps: 50
#  truncated. goal: (-0.11, -0.05, 0.2), steps: 50
#  truncated. goal: (-0.11, -0.05, 0.22), steps: 50
#  truncated. goal: (-0.11, -0.05, 0.24), steps: 50
#  success. goal: (-0.11, -0.05, 0.26), steps: 16
#  success. goal: (-0.11, -0.05, 0.28), steps: 6
#  success. goal: (-0.11, -0.05, 0.3), steps: 6
#  truncated. goal: (-0.11, -0.03, 0.0), steps: 50
#  truncated. goal: (-0.11, -0.03, 0.02), steps: 50
#  truncated. goal: (-0.11, -0.03, 0.04), steps: 50
#  truncated. goal: (-0.11, -0.03, 0.06), steps: 50
#  truncated. goal: (-0.11, -0.03, 0.08), steps: 50
#  truncated. goal: (-0.11, -0.03, 0.1), steps: 50
#  truncated. goal: (-0.11, -0.03, 0.12), steps: 50
#  truncated. goal: (-0.11, -0.03, 0.14), steps: 50
#  truncated. goal: (-0.11, -0.03, 0.16), steps: 50
#  truncated. goal: (-0.11, -0.03, 0.18), steps: 50
#  truncated. goal: (-0.11, -0.03, 0.2), steps: 50
#  truncated. goal: (-0.11, -0.03, 0.22), steps: 50
#  truncated. goal: (-0.11, -0.03, 0.24), steps: 50
#  success. goal: (-0.11, -0.03, 0.26), steps: 6
#  success. goal: (-0.11, -0.03, 0.28), steps: 6
#  success. goal: (-0.11, -0.03, 0.3), steps: 6
#  truncated. goal: (-0.11, -0.01, 0.0), steps: 50
#  truncated. goal: (-0.11, -0.01, 0.02), steps: 50
#  truncated. goal: (-0.11, -0.01, 0.04), steps: 50
#  truncated. goal: (-0.11, -0.01, 0.06), steps: 50
#  truncated. goal: (-0.11, -0.01, 0.08), steps: 50
#  truncated. goal: (-0.11, -0.01, 0.1), steps: 50
#  truncated. goal: (-0.11, -0.01, 0.12), steps: 50
#  success. goal: (-0.11, -0.01, 0.14), steps: 6
#  success. goal: (-0.11, -0.01, 0.16), steps: 6
#  truncated. goal: (-0.11, -0.01, 0.18), steps: 50
#  truncated. goal: (-0.11, -0.01, 0.2), steps: 50
#  truncated. goal: (-0.11, -0.01, 0.22), steps: 50
#  truncated. goal: (-0.11, -0.01, 0.24), steps: 50
#  truncated. goal: (-0.11, -0.01, 0.26), steps: 50
#  success. goal: (-0.11, -0.01, 0.28), steps: 6
#  success. goal: (-0.11, -0.01, 0.3), steps: 7
#  truncated. goal: (-0.11, 0.01, 0.0), steps: 50
#  truncated. goal: (-0.11, 0.01, 0.02), steps: 50
#  truncated. goal: (-0.11, 0.01, 0.04), steps: 50
#  truncated. goal: (-0.11, 0.01, 0.06), steps: 50
#  success. goal: (-0.11, 0.01, 0.08), steps: 5
#  success. goal: (-0.11, 0.01, 0.1), steps: 6
#  success. goal: (-0.11, 0.01, 0.12), steps: 6
#  success. goal: (-0.11, 0.01, 0.14), steps: 6
#  success. goal: (-0.11, 0.01, 0.16), steps: 6
#  success. goal: (-0.11, 0.01, 0.18), steps: 6
#  truncated. goal: (-0.11, 0.01, 0.2), steps: 50
#  truncated. goal: (-0.11, 0.01, 0.22), steps: 50
#  truncated. goal: (-0.11, 0.01, 0.24), steps: 50
#  success. goal: (-0.11, 0.01, 0.26), steps: 6
#  success. goal: (-0.11, 0.01, 0.28), steps: 6
#  success. goal: (-0.11, 0.01, 0.3), steps: 7
#  truncated. goal: (-0.11, 0.03, 0.0), steps: 50
#  truncated. goal: (-0.11, 0.03, 0.02), steps: 50
#  truncated. goal: (-0.11, 0.03, 0.04), steps: 50
#  truncated. goal: (-0.11, 0.03, 0.06), steps: 50
#  success. goal: (-0.11, 0.03, 0.08), steps: 5
#  success. goal: (-0.11, 0.03, 0.1), steps: 5
#  success. goal: (-0.11, 0.03, 0.12), steps: 5
#  success. goal: (-0.11, 0.03, 0.14), steps: 5
#  success. goal: (-0.11, 0.03, 0.16), steps: 5
#  success. goal: (-0.11, 0.03, 0.18), steps: 5
#  success. goal: (-0.11, 0.03, 0.2), steps: 6
#  success. goal: (-0.11, 0.03, 0.22), steps: 5
#  success. goal: (-0.11, 0.03, 0.24), steps: 6
#  success. goal: (-0.11, 0.03, 0.26), steps: 6
#  truncated. goal: (-0.11, 0.03, 0.28), steps: 50
#  truncated. goal: (-0.11, 0.03, 0.3), steps: 50
#  truncated. goal: (-0.11, 0.05, 0.0), steps: 50
#  truncated. goal: (-0.11, 0.05, 0.02), steps: 50
#  truncated. goal: (-0.11, 0.05, 0.04), steps: 50
#  success. goal: (-0.11, 0.05, 0.06), steps: 18
#  success. goal: (-0.11, 0.05, 0.08), steps: 5
#  success. goal: (-0.11, 0.05, 0.1), steps: 5
#  success. goal: (-0.11, 0.05, 0.12), steps: 5
#  success. goal: (-0.11, 0.05, 0.14), steps: 5
#  success. goal: (-0.11, 0.05, 0.16), steps: 5
#  success. goal: (-0.11, 0.05, 0.18), steps: 5
#  success. goal: (-0.11, 0.05, 0.2), steps: 5
#  success. goal: (-0.11, 0.05, 0.22), steps: 5
#  success. goal: (-0.11, 0.05, 0.24), steps: 6
#  success. goal: (-0.11, 0.05, 0.26), steps: 6
#  truncated. goal: (-0.11, 0.05, 0.28), steps: 50
#  truncated. goal: (-0.11, 0.05, 0.3), steps: 50
#  truncated. goal: (-0.11, 0.07, 0.0), steps: 50
#  truncated. goal: (-0.11, 0.07, 0.02), steps: 50
#  success. goal: (-0.11, 0.07, 0.04), steps: 14
#  success. goal: (-0.11, 0.07, 0.06), steps: 5
#  success. goal: (-0.11, 0.07, 0.08), steps: 17
#  success. goal: (-0.11, 0.07, 0.1), steps: 17
#  success. goal: (-0.11, 0.07, 0.12), steps: 18
#  success. goal: (-0.11, 0.07, 0.14), steps: 5
#  success. goal: (-0.11, 0.07, 0.16), steps: 5
#  success. goal: (-0.11, 0.07, 0.18), steps: 5
#  success. goal: (-0.11, 0.07, 0.2), steps: 6
#  success. goal: (-0.11, 0.07, 0.22), steps: 6
#  success. goal: (-0.11, 0.07, 0.24), steps: 6
#  success. goal: (-0.11, 0.07, 0.26), steps: 6
#  truncated. goal: (-0.11, 0.07, 0.28), steps: 50
#  truncated. goal: (-0.11, 0.07, 0.3), steps: 50
#  truncated. goal: (-0.11, 0.09, 0.0), steps: 50
#  truncated. goal: (-0.11, 0.09, 0.02), steps: 50
#  truncated. goal: (-0.11, 0.09, 0.04), steps: 50
#  success. goal: (-0.11, 0.09, 0.06), steps: 5
#  success. goal: (-0.11, 0.09, 0.08), steps: 17
#  success. goal: (-0.11, 0.09, 0.1), steps: 18
#  success. goal: (-0.11, 0.09, 0.12), steps: 19
#  success. goal: (-0.11, 0.09, 0.14), steps: 5
#  success. goal: (-0.11, 0.09, 0.16), steps: 5
#  success. goal: (-0.11, 0.09, 0.18), steps: 5
#  success. goal: (-0.11, 0.09, 0.2), steps: 6
#  success. goal: (-0.11, 0.09, 0.22), steps: 6
#  success. goal: (-0.11, 0.09, 0.24), steps: 6
#  success. goal: (-0.11, 0.09, 0.26), steps: 6
#  success. goal: (-0.11, 0.09, 0.28), steps: 7
#  truncated. goal: (-0.11, 0.09, 0.3), steps: 50
#  truncated. goal: (-0.11, 0.11, 0.0), steps: 50
#  truncated. goal: (-0.11, 0.11, 0.02), steps: 50
#  success. goal: (-0.11, 0.11, 0.04), steps: 17
#  success. goal: (-0.11, 0.11, 0.06), steps: 19
#  success. goal: (-0.11, 0.11, 0.08), steps: 20
#  success. goal: (-0.11, 0.11, 0.1), steps: 5
#  success. goal: (-0.11, 0.11, 0.12), steps: 5
#  success. goal: (-0.11, 0.11, 0.14), steps: 5
#  success. goal: (-0.11, 0.11, 0.16), steps: 5
#  truncated. goal: (-0.11, 0.11, 0.18), steps: 50
#  success. goal: (-0.11, 0.11, 0.2), steps: 6
#  success. goal: (-0.11, 0.11, 0.22), steps: 7
#  success. goal: (-0.11, 0.11, 0.24), steps: 7
#  success. goal: (-0.11, 0.11, 0.26), steps: 7
#  success. goal: (-0.11, 0.11, 0.28), steps: 8
#  truncated. goal: (-0.11, 0.11, 0.3), steps: 50
#  success. goal: (-0.11, 0.13, 0.0), steps: 6
#  success. goal: (-0.11, 0.13, 0.02), steps: 6
#  success. goal: (-0.11, 0.13, 0.04), steps: 6
#  success. goal: (-0.11, 0.13, 0.06), steps: 6
#  success. goal: (-0.11, 0.13, 0.08), steps: 6
#  success. goal: (-0.11, 0.13, 0.1), steps: 6
#  truncated. goal: (-0.11, 0.13, 0.12), steps: 50
#  truncated. goal: (-0.11, 0.13, 0.14), steps: 50
#  success. goal: (-0.11, 0.13, 0.16), steps: 6
#  success. goal: (-0.11, 0.13, 0.18), steps: 6
#  success. goal: (-0.11, 0.13, 0.2), steps: 7
#  success. goal: (-0.11, 0.13, 0.22), steps: 7
#  success. goal: (-0.11, 0.13, 0.24), steps: 8
#  success. goal: (-0.11, 0.13, 0.26), steps: 8
#  success. goal: (-0.11, 0.13, 0.28), steps: 9
#  truncated. goal: (-0.11, 0.13, 0.3), steps: 50
#  success. goal: (-0.11, 0.15, 0.0), steps: 7
#  success. goal: (-0.11, 0.15, 0.02), steps: 7
#  success. goal: (-0.11, 0.15, 0.04), steps: 6
#  success. goal: (-0.11, 0.15, 0.06), steps: 6
#  success. goal: (-0.11, 0.15, 0.08), steps: 6
#  success. goal: (-0.11, 0.15, 0.1), steps: 6
#  success. goal: (-0.11, 0.15, 0.12), steps: 6
#  success. goal: (-0.11, 0.15, 0.14), steps: 6
#  success. goal: (-0.11, 0.15, 0.16), steps: 7
#  success. goal: (-0.11, 0.15, 0.18), steps: 7
#  success. goal: (-0.11, 0.15, 0.2), steps: 7
#  success. goal: (-0.11, 0.15, 0.22), steps: 8
#  success. goal: (-0.11, 0.15, 0.24), steps: 8
#  success. goal: (-0.11, 0.15, 0.26), steps: 9
#  success. goal: (-0.11, 0.15, 0.28), steps: 9
#  truncated. goal: (-0.11, 0.15, 0.3), steps: 50
#  truncated. goal: (-0.09, -0.15, 0.0), steps: 50
#  truncated. goal: (-0.09, -0.15, 0.02), steps: 50
#  truncated. goal: (-0.09, -0.15, 0.04), steps: 50
#  truncated. goal: (-0.09, -0.15, 0.06), steps: 50
#  truncated. goal: (-0.09, -0.15, 0.08), steps: 50
#  truncated. goal: (-0.09, -0.15, 0.1), steps: 50
#  success. goal: (-0.09, -0.15, 0.12), steps: 10
#  success. goal: (-0.09, -0.15, 0.14), steps: 9
#  success. goal: (-0.09, -0.15, 0.16), steps: 9
#  success. goal: (-0.09, -0.15, 0.18), steps: 9
#  success. goal: (-0.09, -0.15, 0.2), steps: 9
#  success. goal: (-0.09, -0.15, 0.22), steps: 6
#  success. goal: (-0.09, -0.15, 0.24), steps: 6
#  truncated. goal: (-0.09, -0.15, 0.26), steps: 50
#  success. goal: (-0.09, -0.15, 0.28), steps: 8
#  success. goal: (-0.09, -0.15, 0.3), steps: 8
#  truncated. goal: (-0.09, -0.13, 0.0), steps: 50
#  truncated. goal: (-0.09, -0.13, 0.02), steps: 50
#  truncated. goal: (-0.09, -0.13, 0.04), steps: 50
#  truncated. goal: (-0.09, -0.13, 0.06), steps: 50
#  truncated. goal: (-0.09, -0.13, 0.08), steps: 50
#  truncated. goal: (-0.09, -0.13, 0.1), steps: 50
#  truncated. goal: (-0.09, -0.13, 0.12), steps: 50
#  success. goal: (-0.09, -0.13, 0.14), steps: 9
#  success. goal: (-0.09, -0.13, 0.16), steps: 9
#  success. goal: (-0.09, -0.13, 0.18), steps: 9
#  success. goal: (-0.09, -0.13, 0.2), steps: 6
#  success. goal: (-0.09, -0.13, 0.22), steps: 6
#  success. goal: (-0.09, -0.13, 0.24), steps: 6
#  success. goal: (-0.09, -0.13, 0.26), steps: 7
#  success. goal: (-0.09, -0.13, 0.28), steps: 7
#  success. goal: (-0.09, -0.13, 0.3), steps: 7
#  truncated. goal: (-0.09, -0.11, 0.0), steps: 50
#  truncated. goal: (-0.09, -0.11, 0.02), steps: 50
#  truncated. goal: (-0.09, -0.11, 0.04), steps: 50
#  truncated. goal: (-0.09, -0.11, 0.06), steps: 50
#  truncated. goal: (-0.09, -0.11, 0.08), steps: 50
#  truncated. goal: (-0.09, -0.11, 0.1), steps: 50
#  truncated. goal: (-0.09, -0.11, 0.12), steps: 50
#  success. goal: (-0.09, -0.11, 0.14), steps: 9
#  success. goal: (-0.09, -0.11, 0.16), steps: 9
#  success. goal: (-0.09, -0.11, 0.18), steps: 9
#  success. goal: (-0.09, -0.11, 0.2), steps: 6
#  success. goal: (-0.09, -0.11, 0.22), steps: 6
#  success. goal: (-0.09, -0.11, 0.24), steps: 6
#  success. goal: (-0.09, -0.11, 0.26), steps: 6
#  success. goal: (-0.09, -0.11, 0.28), steps: 6
#  truncated. goal: (-0.09, -0.11, 0.3), steps: 50
#  truncated. goal: (-0.09, -0.09, 0.0), steps: 50
#  truncated. goal: (-0.09, -0.09, 0.02), steps: 50
#  truncated. goal: (-0.09, -0.09, 0.04), steps: 50
#  truncated. goal: (-0.09, -0.09, 0.06), steps: 50
#  truncated. goal: (-0.09, -0.09, 0.08), steps: 50
#  truncated. goal: (-0.09, -0.09, 0.1), steps: 50
#  truncated. goal: (-0.09, -0.09, 0.12), steps: 50
#  truncated. goal: (-0.09, -0.09, 0.14), steps: 50
#  truncated. goal: (-0.09, -0.09, 0.16), steps: 50
#  truncated. goal: (-0.09, -0.09, 0.18), steps: 50
#  success. goal: (-0.09, -0.09, 0.2), steps: 9
#  success. goal: (-0.09, -0.09, 0.22), steps: 6
#  success. goal: (-0.09, -0.09, 0.24), steps: 6
#  success. goal: (-0.09, -0.09, 0.26), steps: 6
#  success. goal: (-0.09, -0.09, 0.28), steps: 6
#  truncated. goal: (-0.09, -0.09, 0.3), steps: 50
#  truncated. goal: (-0.09, -0.07, 0.0), steps: 50
#  truncated. goal: (-0.09, -0.07, 0.02), steps: 50
#  truncated. goal: (-0.09, -0.07, 0.04), steps: 50
#  truncated. goal: (-0.09, -0.07, 0.06), steps: 50
#  truncated. goal: (-0.09, -0.07, 0.08), steps: 50
#  truncated. goal: (-0.09, -0.07, 0.1), steps: 50
#  truncated. goal: (-0.09, -0.07, 0.12), steps: 50
#  truncated. goal: (-0.09, -0.07, 0.14), steps: 50
#  truncated. goal: (-0.09, -0.07, 0.16), steps: 50
#  truncated. goal: (-0.09, -0.07, 0.18), steps: 50
#  success. goal: (-0.09, -0.07, 0.2), steps: 8
#  success. goal: (-0.09, -0.07, 0.22), steps: 8
#  success. goal: (-0.09, -0.07, 0.24), steps: 5
#  success. goal: (-0.09, -0.07, 0.26), steps: 5
#  success. goal: (-0.09, -0.07, 0.28), steps: 6
#  truncated. goal: (-0.09, -0.07, 0.3), steps: 50
#  truncated. goal: (-0.09, -0.05, 0.0), steps: 50
#  truncated. goal: (-0.09, -0.05, 0.02), steps: 50
#  truncated. goal: (-0.09, -0.05, 0.04), steps: 50
#  truncated. goal: (-0.09, -0.05, 0.06), steps: 50
#  truncated. goal: (-0.09, -0.05, 0.08), steps: 50
#  truncated. goal: (-0.09, -0.05, 0.1), steps: 50
#  truncated. goal: (-0.09, -0.05, 0.12), steps: 50
#  truncated. goal: (-0.09, -0.05, 0.14), steps: 50
#  truncated. goal: (-0.09, -0.05, 0.16), steps: 50
#  truncated. goal: (-0.09, -0.05, 0.18), steps: 50
#  truncated. goal: (-0.09, -0.05, 0.2), steps: 50
#  success. goal: (-0.09, -0.05, 0.22), steps: 8
#  success. goal: (-0.09, -0.05, 0.24), steps: 5
#  success. goal: (-0.09, -0.05, 0.26), steps: 12
#  success. goal: (-0.09, -0.05, 0.28), steps: 19
#  success. goal: (-0.09, -0.05, 0.3), steps: 6
#  truncated. goal: (-0.09, -0.03, 0.0), steps: 50
#  truncated. goal: (-0.09, -0.03, 0.02), steps: 50
#  truncated. goal: (-0.09, -0.03, 0.04), steps: 50
#  truncated. goal: (-0.09, -0.03, 0.06), steps: 50
#  truncated. goal: (-0.09, -0.03, 0.08), steps: 50
#  truncated. goal: (-0.09, -0.03, 0.1), steps: 50
#  truncated. goal: (-0.09, -0.03, 0.12), steps: 50
#  truncated. goal: (-0.09, -0.03, 0.14), steps: 50
#  truncated. goal: (-0.09, -0.03, 0.16), steps: 50
#  truncated. goal: (-0.09, -0.03, 0.18), steps: 50
#  truncated. goal: (-0.09, -0.03, 0.2), steps: 50
#  truncated. goal: (-0.09, -0.03, 0.22), steps: 50
#  success. goal: (-0.09, -0.03, 0.24), steps: 14
#  success. goal: (-0.09, -0.03, 0.26), steps: 5
#  success. goal: (-0.09, -0.03, 0.28), steps: 6
#  success. goal: (-0.09, -0.03, 0.3), steps: 6
#  truncated. goal: (-0.09, -0.01, 0.0), steps: 50
#  truncated. goal: (-0.09, -0.01, 0.02), steps: 50
#  truncated. goal: (-0.09, -0.01, 0.04), steps: 50
#  truncated. goal: (-0.09, -0.01, 0.06), steps: 50
#  truncated. goal: (-0.09, -0.01, 0.08), steps: 50
#  truncated. goal: (-0.09, -0.01, 0.1), steps: 50
#  truncated. goal: (-0.09, -0.01, 0.12), steps: 50
#  success. goal: (-0.09, -0.01, 0.14), steps: 6
#  success. goal: (-0.09, -0.01, 0.16), steps: 6
#  truncated. goal: (-0.09, -0.01, 0.18), steps: 50
#  truncated. goal: (-0.09, -0.01, 0.2), steps: 50
#  truncated. goal: (-0.09, -0.01, 0.22), steps: 50
#  truncated. goal: (-0.09, -0.01, 0.24), steps: 50
#  success. goal: (-0.09, -0.01, 0.26), steps: 5
#  success. goal: (-0.09, -0.01, 0.28), steps: 6
#  success. goal: (-0.09, -0.01, 0.3), steps: 6
#  truncated. goal: (-0.09, 0.01, 0.0), steps: 50
#  truncated. goal: (-0.09, 0.01, 0.02), steps: 50
#  truncated. goal: (-0.09, 0.01, 0.04), steps: 50
#  truncated. goal: (-0.09, 0.01, 0.06), steps: 50
#  truncated. goal: (-0.09, 0.01, 0.08), steps: 50
#  truncated. goal: (-0.09, 0.01, 0.1), steps: 50
#  success. goal: (-0.09, 0.01, 0.12), steps: 5
#  success. goal: (-0.09, 0.01, 0.14), steps: 5
#  success. goal: (-0.09, 0.01, 0.16), steps: 5
#  success. goal: (-0.09, 0.01, 0.18), steps: 5
#  truncated. goal: (-0.09, 0.01, 0.2), steps: 50
#  truncated. goal: (-0.09, 0.01, 0.22), steps: 50
#  success. goal: (-0.09, 0.01, 0.24), steps: 5
#  success. goal: (-0.09, 0.01, 0.26), steps: 6
#  success. goal: (-0.09, 0.01, 0.28), steps: 6
#  truncated. goal: (-0.09, 0.01, 0.3), steps: 50
#  truncated. goal: (-0.09, 0.03, 0.0), steps: 50
#  truncated. goal: (-0.09, 0.03, 0.02), steps: 50
#  truncated. goal: (-0.09, 0.03, 0.04), steps: 50
#  truncated. goal: (-0.09, 0.03, 0.06), steps: 50
#  truncated. goal: (-0.09, 0.03, 0.08), steps: 50
#  success. goal: (-0.09, 0.03, 0.1), steps: 5
#  success. goal: (-0.09, 0.03, 0.12), steps: 5
#  success. goal: (-0.09, 0.03, 0.14), steps: 5
#  success. goal: (-0.09, 0.03, 0.16), steps: 5
#  success. goal: (-0.09, 0.03, 0.18), steps: 5
#  success. goal: (-0.09, 0.03, 0.2), steps: 5
#  success. goal: (-0.09, 0.03, 0.22), steps: 5
#  success. goal: (-0.09, 0.03, 0.24), steps: 5
#  success. goal: (-0.09, 0.03, 0.26), steps: 6
#  success. goal: (-0.09, 0.03, 0.28), steps: 6
#  truncated. goal: (-0.09, 0.03, 0.3), steps: 50
#  truncated. goal: (-0.09, 0.05, 0.0), steps: 50
#  truncated. goal: (-0.09, 0.05, 0.02), steps: 50
#  truncated. goal: (-0.09, 0.05, 0.04), steps: 50
#  success. goal: (-0.09, 0.05, 0.06), steps: 13
#  success. goal: (-0.09, 0.05, 0.08), steps: 5
#  success. goal: (-0.09, 0.05, 0.1), steps: 4
#  success. goal: (-0.09, 0.05, 0.12), steps: 4
#  success. goal: (-0.09, 0.05, 0.14), steps: 4
#  success. goal: (-0.09, 0.05, 0.16), steps: 5
#  success. goal: (-0.09, 0.05, 0.18), steps: 5
#  success. goal: (-0.09, 0.05, 0.2), steps: 5
#  success. goal: (-0.09, 0.05, 0.22), steps: 5
#  success. goal: (-0.09, 0.05, 0.24), steps: 5
#  success. goal: (-0.09, 0.05, 0.26), steps: 6
#  truncated. goal: (-0.09, 0.05, 0.28), steps: 50
#  truncated. goal: (-0.09, 0.05, 0.3), steps: 50
#  truncated. goal: (-0.09, 0.07, 0.0), steps: 50
#  truncated. goal: (-0.09, 0.07, 0.02), steps: 50
#  truncated. goal: (-0.09, 0.07, 0.04), steps: 50
#  success. goal: (-0.09, 0.07, 0.06), steps: 12
#  success. goal: (-0.09, 0.07, 0.08), steps: 14
#  success. goal: (-0.09, 0.07, 0.1), steps: 4
#  success. goal: (-0.09, 0.07, 0.12), steps: 4
#  success. goal: (-0.09, 0.07, 0.14), steps: 4
#  success. goal: (-0.09, 0.07, 0.16), steps: 4
#  success. goal: (-0.09, 0.07, 0.18), steps: 5
#  success. goal: (-0.09, 0.07, 0.2), steps: 5
#  success. goal: (-0.09, 0.07, 0.22), steps: 5
#  success. goal: (-0.09, 0.07, 0.24), steps: 6
#  success. goal: (-0.09, 0.07, 0.26), steps: 6
#  success. goal: (-0.09, 0.07, 0.28), steps: 6
#  truncated. goal: (-0.09, 0.07, 0.3), steps: 50
#  truncated. goal: (-0.09, 0.09, 0.0), steps: 50
#  truncated. goal: (-0.09, 0.09, 0.02), steps: 50
#  truncated. goal: (-0.09, 0.09, 0.04), steps: 50
#  success. goal: (-0.09, 0.09, 0.06), steps: 13
#  success. goal: (-0.09, 0.09, 0.08), steps: 5
#  success. goal: (-0.09, 0.09, 0.1), steps: 17
#  success. goal: (-0.09, 0.09, 0.12), steps: 19
#  truncated. goal: (-0.09, 0.09, 0.14), steps: 50
#  success. goal: (-0.09, 0.09, 0.16), steps: 5
#  success. goal: (-0.09, 0.09, 0.18), steps: 5
#  success. goal: (-0.09, 0.09, 0.2), steps: 6
#  success. goal: (-0.09, 0.09, 0.22), steps: 6
#  success. goal: (-0.09, 0.09, 0.24), steps: 6
#  success. goal: (-0.09, 0.09, 0.26), steps: 7
#  success. goal: (-0.09, 0.09, 0.28), steps: 7
#  success. goal: (-0.09, 0.09, 0.3), steps: 7
#  truncated. goal: (-0.09, 0.11, 0.0), steps: 50
#  success. goal: (-0.09, 0.11, 0.02), steps: 6
#  success. goal: (-0.09, 0.11, 0.04), steps: 6
#  success. goal: (-0.09, 0.11, 0.06), steps: 16
#  success. goal: (-0.09, 0.11, 0.08), steps: 6
#  success. goal: (-0.09, 0.11, 0.1), steps: 5
#  success. goal: (-0.09, 0.11, 0.12), steps: 5
# ...
#  truncated. goal: (0.13, 0.05, 0.22), steps: 50
#  success. goal: (0.13, 0.05, 0.24), steps: 5
#  success. goal: (0.13, 0.05, 0.26), steps: 6
#  success. goal: (0.13, 0.05, 0.28), steps: 6
#  success. goal: (0.13, 0.05, 0.3), steps: 7
#  success. goal: (0.13, 0.07, 0.0), steps: 10
#  success. goal: (0.13, 0.07, 0.02), steps: 7
#  success. goal: (0.13, 0.07, 0.04), steps: 6
#  success. goal: (0.13, 0.07, 0.06), steps: 6
#  success. goal: (0.13, 0.07, 0.08), steps: 6
#  success. goal: (0.13, 0.07, 0.1), steps: 6
#  success. goal: (0.13, 0.07, 0.12), steps: 6
#  success. goal: (0.13, 0.07, 0.14), steps: 5
#  success. goal: (0.13, 0.07, 0.16), steps: 5
#  truncated. goal: (0.13, 0.07, 0.18), steps: 50
#  truncated. goal: (0.13, 0.07, 0.2), steps: 50
#  truncated. goal: (0.13, 0.07, 0.22), steps: 50
#  success. goal: (0.13, 0.07, 0.24), steps: 6
#  success. goal: (0.13, 0.07, 0.26), steps: 6
#  truncated. goal: (0.13, 0.07, 0.28), steps: 50
#  truncated. goal: (0.13, 0.07, 0.3), steps: 50
#  success. goal: (0.13, 0.09, 0.0), steps: 10
#  success. goal: (0.13, 0.09, 0.02), steps: 8
#  success. goal: (0.13, 0.09, 0.04), steps: 8
#  success. goal: (0.13, 0.09, 0.06), steps: 6
#  success. goal: (0.13, 0.09, 0.08), steps: 6
#  success. goal: (0.13, 0.09, 0.1), steps: 6
#  success. goal: (0.13, 0.09, 0.12), steps: 6
#  success. goal: (0.13, 0.09, 0.14), steps: 5
#  success. goal: (0.13, 0.09, 0.16), steps: 5
#  success. goal: (0.13, 0.09, 0.18), steps: 5
#  truncated. goal: (0.13, 0.09, 0.2), steps: 50
#  success. goal: (0.13, 0.09, 0.22), steps: 6
#  success. goal: (0.13, 0.09, 0.24), steps: 6
#  success. goal: (0.13, 0.09, 0.26), steps: 6
#  success. goal: (0.13, 0.09, 0.28), steps: 7
#  truncated. goal: (0.13, 0.09, 0.3), steps: 50
#  success. goal: (0.13, 0.11, 0.0), steps: 16
#  success. goal: (0.13, 0.11, 0.02), steps: 11
#  success. goal: (0.13, 0.11, 0.04), steps: 10
#  success. goal: (0.13, 0.11, 0.06), steps: 11
#  success. goal: (0.13, 0.11, 0.08), steps: 7
#  success. goal: (0.13, 0.11, 0.1), steps: 6
#  success. goal: (0.13, 0.11, 0.12), steps: 6
#  success. goal: (0.13, 0.11, 0.14), steps: 6
#  success. goal: (0.13, 0.11, 0.16), steps: 6
#  success. goal: (0.13, 0.11, 0.18), steps: 6
#  success. goal: (0.13, 0.11, 0.2), steps: 6
#  success. goal: (0.13, 0.11, 0.22), steps: 6
#  success. goal: (0.13, 0.11, 0.24), steps: 6
#  success. goal: (0.13, 0.11, 0.26), steps: 7
#  success. goal: (0.13, 0.11, 0.28), steps: 7
#  success. goal: (0.13, 0.11, 0.3), steps: 8
#  truncated. goal: (0.13, 0.13, 0.0), steps: 50
#  truncated. goal: (0.13, 0.13, 0.02), steps: 50
#  success. goal: (0.13, 0.13, 0.04), steps: 20
#  success. goal: (0.13, 0.13, 0.06), steps: 7
#  success. goal: (0.13, 0.13, 0.08), steps: 7
#  success. goal: (0.13, 0.13, 0.1), steps: 7
#  success. goal: (0.13, 0.13, 0.12), steps: 7
#  success. goal: (0.13, 0.13, 0.14), steps: 7
#  success. goal: (0.13, 0.13, 0.16), steps: 7
#  success. goal: (0.13, 0.13, 0.18), steps: 7
#  success. goal: (0.13, 0.13, 0.2), steps: 7
#  success. goal: (0.13, 0.13, 0.22), steps: 7
#  success. goal: (0.13, 0.13, 0.24), steps: 7
#  success. goal: (0.13, 0.13, 0.26), steps: 7
#  success. goal: (0.13, 0.13, 0.28), steps: 8
#  success. goal: (0.13, 0.13, 0.3), steps: 8
#  truncated. goal: (0.13, 0.15, 0.0), steps: 50
#  truncated. goal: (0.13, 0.15, 0.02), steps: 50
#  success. goal: (0.13, 0.15, 0.04), steps: 8
#  success. goal: (0.13, 0.15, 0.06), steps: 8
#  success. goal: (0.13, 0.15, 0.08), steps: 8
#  success. goal: (0.13, 0.15, 0.1), steps: 8
#  success. goal: (0.13, 0.15, 0.12), steps: 8
#  success. goal: (0.13, 0.15, 0.14), steps: 8
#  success. goal: (0.13, 0.15, 0.16), steps: 8
#  success. goal: (0.13, 0.15, 0.18), steps: 8
#  success. goal: (0.13, 0.15, 0.2), steps: 7
#  success. goal: (0.13, 0.15, 0.22), steps: 8
#  success. goal: (0.13, 0.15, 0.24), steps: 8
#  success. goal: (0.13, 0.15, 0.26), steps: 8
#  success. goal: (0.13, 0.15, 0.28), steps: 8
#  success. goal: (0.13, 0.15, 0.3), steps: 9
#  truncated. goal: (0.15, -0.15, 0.0), steps: 50
#  truncated. goal: (0.15, -0.15, 0.02), steps: 50
#  truncated. goal: (0.15, -0.15, 0.04), steps: 50
#  truncated. goal: (0.15, -0.15, 0.06), steps: 50
#  success. goal: (0.15, -0.15, 0.08), steps: 10
#  success. goal: (0.15, -0.15, 0.1), steps: 10
#  success. goal: (0.15, -0.15, 0.12), steps: 9
#  success. goal: (0.15, -0.15, 0.14), steps: 13
#  truncated. goal: (0.15, -0.15, 0.16), steps: 50
#  truncated. goal: (0.15, -0.15, 0.18), steps: 50
#  success. goal: (0.15, -0.15, 0.2), steps: 31
#  success. goal: (0.15, -0.15, 0.22), steps: 23
#  success. goal: (0.15, -0.15, 0.24), steps: 21
#  success. goal: (0.15, -0.15, 0.26), steps: 21
#  success. goal: (0.15, -0.15, 0.28), steps: 23
#  truncated. goal: (0.15, -0.15, 0.3), steps: 50
#  truncated. goal: (0.15, -0.13, 0.0), steps: 50
#  truncated. goal: (0.15, -0.13, 0.02), steps: 50
#  truncated. goal: (0.15, -0.13, 0.04), steps: 50
#  truncated. goal: (0.15, -0.13, 0.06), steps: 50
#  truncated. goal: (0.15, -0.13, 0.08), steps: 50
#  success. goal: (0.15, -0.13, 0.1), steps: 11
#  success. goal: (0.15, -0.13, 0.12), steps: 8
#  success. goal: (0.15, -0.13, 0.14), steps: 7
#  success. goal: (0.15, -0.13, 0.16), steps: 7
#  truncated. goal: (0.15, -0.13, 0.18), steps: 50
#  success. goal: (0.15, -0.13, 0.2), steps: 21
#  success. goal: (0.15, -0.13, 0.22), steps: 17
#  success. goal: (0.15, -0.13, 0.24), steps: 15
#  success. goal: (0.15, -0.13, 0.26), steps: 14
#  success. goal: (0.15, -0.13, 0.28), steps: 16
#  success. goal: (0.15, -0.13, 0.3), steps: 19
#  truncated. goal: (0.15, -0.11, 0.0), steps: 50
#  truncated. goal: (0.15, -0.11, 0.02), steps: 50
#  truncated. goal: (0.15, -0.11, 0.04), steps: 50
#  truncated. goal: (0.15, -0.11, 0.06), steps: 50
#  success. goal: (0.15, -0.11, 0.08), steps: 12
#  success. goal: (0.15, -0.11, 0.1), steps: 10
#  success. goal: (0.15, -0.11, 0.12), steps: 7
#  success. goal: (0.15, -0.11, 0.14), steps: 7
#  success. goal: (0.15, -0.11, 0.16), steps: 7
#  truncated. goal: (0.15, -0.11, 0.18), steps: 50
#  truncated. goal: (0.15, -0.11, 0.2), steps: 50
#  truncated. goal: (0.15, -0.11, 0.22), steps: 50
#  success. goal: (0.15, -0.11, 0.24), steps: 10
#  success. goal: (0.15, -0.11, 0.26), steps: 10
#  success. goal: (0.15, -0.11, 0.28), steps: 11
#  success. goal: (0.15, -0.11, 0.3), steps: 13
#  truncated. goal: (0.15, -0.09, 0.0), steps: 50
#  truncated. goal: (0.15, -0.09, 0.02), steps: 50
#  success. goal: (0.15, -0.09, 0.04), steps: 14
#  success. goal: (0.15, -0.09, 0.06), steps: 9
#  success. goal: (0.15, -0.09, 0.08), steps: 9
#  success. goal: (0.15, -0.09, 0.1), steps: 8
#  success. goal: (0.15, -0.09, 0.12), steps: 7
#  success. goal: (0.15, -0.09, 0.14), steps: 7
#  success. goal: (0.15, -0.09, 0.16), steps: 7
#  truncated. goal: (0.15, -0.09, 0.18), steps: 50
#  truncated. goal: (0.15, -0.09, 0.2), steps: 50
#  success. goal: (0.15, -0.09, 0.22), steps: 6
#  success. goal: (0.15, -0.09, 0.24), steps: 6
#  success. goal: (0.15, -0.09, 0.26), steps: 9
#  success. goal: (0.15, -0.09, 0.28), steps: 10
#  success. goal: (0.15, -0.09, 0.3), steps: 11
#  success. goal: (0.15, -0.07, 0.0), steps: 19
#  success. goal: (0.15, -0.07, 0.02), steps: 19
#  success. goal: (0.15, -0.07, 0.04), steps: 11
#  success. goal: (0.15, -0.07, 0.06), steps: 8
#  success. goal: (0.15, -0.07, 0.08), steps: 8
#  success. goal: (0.15, -0.07, 0.1), steps: 7
#  success. goal: (0.15, -0.07, 0.12), steps: 7
#  success. goal: (0.15, -0.07, 0.14), steps: 7
#  success. goal: (0.15, -0.07, 0.16), steps: 6
#  success. goal: (0.15, -0.07, 0.18), steps: 6
#  success. goal: (0.15, -0.07, 0.2), steps: 6
#  success. goal: (0.15, -0.07, 0.22), steps: 6
#  success. goal: (0.15, -0.07, 0.24), steps: 6
#  success. goal: (0.15, -0.07, 0.26), steps: 7
#  success. goal: (0.15, -0.07, 0.28), steps: 9
#  success. goal: (0.15, -0.07, 0.3), steps: 10
#  success. goal: (0.15, -0.05, 0.0), steps: 11
#  success. goal: (0.15, -0.05, 0.02), steps: 16
#  success. goal: (0.15, -0.05, 0.04), steps: 9
#  success. goal: (0.15, -0.05, 0.06), steps: 8
#  success. goal: (0.15, -0.05, 0.08), steps: 8
#  success. goal: (0.15, -0.05, 0.1), steps: 7
#  success. goal: (0.15, -0.05, 0.12), steps: 7
#  success. goal: (0.15, -0.05, 0.14), steps: 6
#  success. goal: (0.15, -0.05, 0.16), steps: 6
#  success. goal: (0.15, -0.05, 0.18), steps: 6
#  success. goal: (0.15, -0.05, 0.2), steps: 6
#  success. goal: (0.15, -0.05, 0.22), steps: 6
#  success. goal: (0.15, -0.05, 0.24), steps: 6
#  success. goal: (0.15, -0.05, 0.26), steps: 7
#  success. goal: (0.15, -0.05, 0.28), steps: 8
#  success. goal: (0.15, -0.05, 0.3), steps: 9
#  success. goal: (0.15, -0.03, 0.0), steps: 9
#  success. goal: (0.15, -0.03, 0.02), steps: 16
#  success. goal: (0.15, -0.03, 0.04), steps: 8
#  success. goal: (0.15, -0.03, 0.06), steps: 8
#  success. goal: (0.15, -0.03, 0.08), steps: 8
#  success. goal: (0.15, -0.03, 0.1), steps: 7
#  success. goal: (0.15, -0.03, 0.12), steps: 7
#  success. goal: (0.15, -0.03, 0.14), steps: 6
#  success. goal: (0.15, -0.03, 0.16), steps: 7
#  success. goal: (0.15, -0.03, 0.18), steps: 6
#  success. goal: (0.15, -0.03, 0.2), steps: 6
#  success. goal: (0.15, -0.03, 0.22), steps: 6
#  success. goal: (0.15, -0.03, 0.24), steps: 6
#  success. goal: (0.15, -0.03, 0.26), steps: 7
#  success. goal: (0.15, -0.03, 0.28), steps: 8
#  success. goal: (0.15, -0.03, 0.3), steps: 8
#  success. goal: (0.15, -0.01, 0.0), steps: 10
#  success. goal: (0.15, -0.01, 0.02), steps: 17
#  success. goal: (0.15, -0.01, 0.04), steps: 8
#  success. goal: (0.15, -0.01, 0.06), steps: 8
#  success. goal: (0.15, -0.01, 0.08), steps: 7
#  success. goal: (0.15, -0.01, 0.1), steps: 7
#  success. goal: (0.15, -0.01, 0.12), steps: 6
#  success. goal: (0.15, -0.01, 0.14), steps: 6
#  success. goal: (0.15, -0.01, 0.16), steps: 6
#  success. goal: (0.15, -0.01, 0.18), steps: 6
#  success. goal: (0.15, -0.01, 0.2), steps: 6
#  success. goal: (0.15, -0.01, 0.22), steps: 6
#  success. goal: (0.15, -0.01, 0.24), steps: 6
#  success. goal: (0.15, -0.01, 0.26), steps: 6
#  success. goal: (0.15, -0.01, 0.28), steps: 7
#  success. goal: (0.15, -0.01, 0.3), steps: 8
#  success. goal: (0.15, 0.01, 0.0), steps: 10
#  success. goal: (0.15, 0.01, 0.02), steps: 15
#  success. goal: (0.15, 0.01, 0.04), steps: 7
#  success. goal: (0.15, 0.01, 0.06), steps: 8
#  success. goal: (0.15, 0.01, 0.08), steps: 7
#  success. goal: (0.15, 0.01, 0.1), steps: 6
#  success. goal: (0.15, 0.01, 0.12), steps: 6
#  success. goal: (0.15, 0.01, 0.14), steps: 6
#  success. goal: (0.15, 0.01, 0.16), steps: 6
#  success. goal: (0.15, 0.01, 0.18), steps: 6
#  success. goal: (0.15, 0.01, 0.2), steps: 6
#  success. goal: (0.15, 0.01, 0.22), steps: 6
#  success. goal: (0.15, 0.01, 0.24), steps: 6
#  success. goal: (0.15, 0.01, 0.26), steps: 6
#  success. goal: (0.15, 0.01, 0.28), steps: 7
#  success. goal: (0.15, 0.01, 0.3), steps: 8
#  success. goal: (0.15, 0.03, 0.0), steps: 10
#  success. goal: (0.15, 0.03, 0.02), steps: 13
#  success. goal: (0.15, 0.03, 0.04), steps: 8
#  success. goal: (0.15, 0.03, 0.06), steps: 7
#  success. goal: (0.15, 0.03, 0.08), steps: 7
#  success. goal: (0.15, 0.03, 0.1), steps: 7
#  success. goal: (0.15, 0.03, 0.12), steps: 6
#  success. goal: (0.15, 0.03, 0.14), steps: 6
#  success. goal: (0.15, 0.03, 0.16), steps: 6
#  success. goal: (0.15, 0.03, 0.18), steps: 6
#  truncated. goal: (0.15, 0.03, 0.2), steps: 50
#  truncated. goal: (0.15, 0.03, 0.22), steps: 50
#  success. goal: (0.15, 0.03, 0.24), steps: 6
#  success. goal: (0.15, 0.03, 0.26), steps: 7
#  success. goal: (0.15, 0.03, 0.28), steps: 7
#  success. goal: (0.15, 0.03, 0.3), steps: 8
#  success. goal: (0.15, 0.05, 0.0), steps: 10
#  success. goal: (0.15, 0.05, 0.02), steps: 11
#  success. goal: (0.15, 0.05, 0.04), steps: 8
#  success. goal: (0.15, 0.05, 0.06), steps: 7
#  success. goal: (0.15, 0.05, 0.08), steps: 7
#  success. goal: (0.15, 0.05, 0.1), steps: 7
#  success. goal: (0.15, 0.05, 0.12), steps: 7
#  success. goal: (0.15, 0.05, 0.14), steps: 6
#  success. goal: (0.15, 0.05, 0.16), steps: 7
#  success. goal: (0.15, 0.05, 0.18), steps: 7
#  truncated. goal: (0.15, 0.05, 0.2), steps: 50
#  truncated. goal: (0.15, 0.05, 0.22), steps: 50
#  truncated. goal: (0.15, 0.05, 0.24), steps: 50
#  success. goal: (0.15, 0.05, 0.26), steps: 7
#  success. goal: (0.15, 0.05, 0.28), steps: 7
#  success. goal: (0.15, 0.05, 0.3), steps: 8
#  success. goal: (0.15, 0.07, 0.0), steps: 11
#  success. goal: (0.15, 0.07, 0.02), steps: 10
#  success. goal: (0.15, 0.07, 0.04), steps: 9
#  success. goal: (0.15, 0.07, 0.06), steps: 8
#  success. goal: (0.15, 0.07, 0.08), steps: 7
#  success. goal: (0.15, 0.07, 0.1), steps: 7
#  success. goal: (0.15, 0.07, 0.12), steps: 7
#  success. goal: (0.15, 0.07, 0.14), steps: 6
#  success. goal: (0.15, 0.07, 0.16), steps: 7
#  success. goal: (0.15, 0.07, 0.18), steps: 8
#  truncated. goal: (0.15, 0.07, 0.2), steps: 50
#  truncated. goal: (0.15, 0.07, 0.22), steps: 50
#  truncated. goal: (0.15, 0.07, 0.24), steps: 50
#  truncated. goal: (0.15, 0.07, 0.26), steps: 50
#  truncated. goal: (0.15, 0.07, 0.28), steps: 50
#  success. goal: (0.15, 0.07, 0.3), steps: 9
#  success. goal: (0.15, 0.09, 0.0), steps: 11
#  success. goal: (0.15, 0.09, 0.02), steps: 10
#  success. goal: (0.15, 0.09, 0.04), steps: 10
#  success. goal: (0.15, 0.09, 0.06), steps: 11
#  success. goal: (0.15, 0.09, 0.08), steps: 9
#  success. goal: (0.15, 0.09, 0.1), steps: 7
#  success. goal: (0.15, 0.09, 0.12), steps: 7
#  success. goal: (0.15, 0.09, 0.14), steps: 6
#  success. goal: (0.15, 0.09, 0.16), steps: 7
#  success. goal: (0.15, 0.09, 0.18), steps: 8
#  success. goal: (0.15, 0.09, 0.2), steps: 10
#  success. goal: (0.15, 0.09, 0.22), steps: 10
#  success. goal: (0.15, 0.09, 0.24), steps: 10
#  success. goal: (0.15, 0.09, 0.26), steps: 8
#  success. goal: (0.15, 0.09, 0.28), steps: 9
#  success. goal: (0.15, 0.09, 0.3), steps: 9
#  success. goal: (0.15, 0.11, 0.0), steps: 14
#  success. goal: (0.15, 0.11, 0.02), steps: 15
#  success. goal: (0.15, 0.11, 0.04), steps: 17
#  success. goal: (0.15, 0.11, 0.06), steps: 17
#  success. goal: (0.15, 0.11, 0.08), steps: 15
#  success. goal: (0.15, 0.11, 0.1), steps: 9
#  success. goal: (0.15, 0.11, 0.12), steps: 7
#  success. goal: (0.15, 0.11, 0.14), steps: 7
#  success. goal: (0.15, 0.11, 0.16), steps: 7
#  success. goal: (0.15, 0.11, 0.18), steps: 7
#  success. goal: (0.15, 0.11, 0.2), steps: 7
#  success. goal: (0.15, 0.11, 0.22), steps: 8
#  success. goal: (0.15, 0.11, 0.24), steps: 8
#  success. goal: (0.15, 0.11, 0.26), steps: 8
#  success. goal: (0.15, 0.11, 0.28), steps: 9
#  success. goal: (0.15, 0.11, 0.3), steps: 10
#  success. goal: (0.15, 0.13, 0.0), steps: 22
#  success. goal: (0.15, 0.13, 0.02), steps: 22
#  truncated. goal: (0.15, 0.13, 0.04), steps: 50
#  truncated. goal: (0.15, 0.13, 0.06), steps: 50
#  truncated. goal: (0.15, 0.13, 0.08), steps: 50
#  success. goal: (0.15, 0.13, 0.1), steps: 8
#  success. goal: (0.15, 0.13, 0.12), steps: 7
#  success. goal: (0.15, 0.13, 0.14), steps: 7
#  success. goal: (0.15, 0.13, 0.16), steps: 8
#  success. goal: (0.15, 0.13, 0.18), steps: 8
#  success. goal: (0.15, 0.13, 0.2), steps: 8
#  success. goal: (0.15, 0.13, 0.22), steps: 8
#  success. goal: (0.15, 0.13, 0.24), steps: 9
#  success. goal: (0.15, 0.13, 0.26), steps: 9
#  success. goal: (0.15, 0.13, 0.28), steps: 9
#  success. goal: (0.15, 0.13, 0.3), steps: 11
#  truncated. goal: (0.15, 0.15, 0.0), steps: 50
#  truncated. goal: (0.15, 0.15, 0.02), steps: 50
#  truncated. goal: (0.15, 0.15, 0.04), steps: 50
#  truncated. goal: (0.15, 0.15, 0.06), steps: 50
#  success. goal: (0.15, 0.15, 0.08), steps: 8
#  success. goal: (0.15, 0.15, 0.1), steps: 8
#  success. goal: (0.15, 0.15, 0.12), steps: 8
#  success. goal: (0.15, 0.15, 0.14), steps: 8
#  success. goal: (0.15, 0.15, 0.16), steps: 8
#  success. goal: (0.15, 0.15, 0.18), steps: 9
#  success. goal: (0.15, 0.15, 0.2), steps: 9
#  success. goal: (0.15, 0.15, 0.22), steps: 9
#  success. goal: (0.15, 0.15, 0.24), steps: 10
#  success. goal: (0.15, 0.15, 0.26), steps: 11
#  success. goal: (0.15, 0.15, 0.28), steps: 12
#  truncated. goal: (0.15, 0.15, 0.3), steps: 50
# 2695

# %%
total_df
# Out:
#          s_x           s_y       s_z         s_v_x         s_v_y  \
# 0   0.038440 -2.845172e-12  0.197400 -2.227948e-09  5.934769e-11
# 1   0.012749 -2.571467e-02  0.194471 -2.681201e-01 -1.240516e+00
# 2  -0.019951 -6.730323e-02  0.191532 -4.324457e-01 -3.996804e-01
# 3  -0.048744 -9.259280e-02  0.192626 -1.921438e-01 -2.722411e-01
# 4  -0.077410 -1.182547e-01  0.190659 -3.708776e-01 -3.681294e-01
# ..       ...           ...       ...           ...           ...
# 7   0.134086  1.375646e-01  0.258653  3.742145e-02  1.093792e-01
# 8   0.136880  1.442531e-01  0.266102  2.187905e-02  5.616264e-02
# 9   0.138971  1.463822e-01  0.270720  1.655194e-02  1.547260e-02
# 10  0.141016  1.459456e-01  0.273284  1.561577e-02 -3.725023e-03
# 11  0.143109  1.447531e-01  0.274713  1.588911e-02 -9.643510e-03
#
#            s_v_z  s_g_x  s_g_y  s_g_z       a_x       a_y       a_z
# 0   5.533001e-09  -0.15  -0.15   0.18 -0.818392 -1.000000 -0.026094
# 1   1.325766e-01  -0.15  -0.15   0.18 -1.000000 -0.739918 -0.103200
# 2  -6.455885e-02  -0.15  -0.15   0.18 -0.767588 -0.587459  0.073793
# 3   1.516464e-01  -0.15  -0.15   0.18 -0.828790 -0.612349 -0.069604
# 4  -5.332219e-02  -0.15  -0.15   0.18 -0.560042 -0.487128  0.086997
# ..           ...    ...    ...    ...       ...       ...       ...
# 7   1.202703e-01   0.15   0.15   0.28  0.310955  0.205043  0.231976
# 8   7.397930e-02   0.15   0.15   0.28  0.226537  0.084572  0.147792
# 9   3.929159e-02   0.15   0.15   0.28  0.187572  0.017968  0.091029
# 10  1.993250e-02   0.15   0.15   0.28  0.176052 -0.002270  0.062020
# 11  1.077073e-02   0.15   0.15   0.28  0.175347 -0.003283  0.048018
#
# [17943 rows x 12 columns]

# %%
len(total_df) / success_cnt
# Out:
# 6.657884972170686

# %%
total_df.to_csv(csv_save_name, index=False)
